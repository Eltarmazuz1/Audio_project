# %%
# !git clone https://github.com/Eltarmazuz1/Audio_project.git
# Out:
# Cloning into 'Audio_Project'...
# remote: Enumerating objects: 362, done.
# remote: Counting objects: 100% (362/362), done.
# remote: Compressing objects: 100% (180/180), done.
# remote: Total 362 (delta 201), reused 303 (delta 160), pack-reused 0 (from 0)
# Receiving objects: 100% (362/362), 3.24 MiB | 18.13 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %%
# %cd Audio_Project
# Out:
# /content/Audio_Project

# %% [markdown]
# # fluent-speech-commands-dataset

# %%
# !pip install numpy torch torchaudio torchvision wandb transformers==4.28.1 librosa
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.9)
# Collecting transformers==4.28.1
#   Downloading transformers-4.28.1-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (0.30.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (2.32.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.1)
#   Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.28.1) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.28.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.28.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.28.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.28.1) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 64.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.1 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.8 MB/s eta 0:00:00
# Installing collected packages: tokenizers, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, transformers, nvidia-cusolver-cu12
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.3
#     Uninstalling transformers-4.50.3:
#       Successfully uninstalled transformers-4.50.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.28.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 tokenizers-0.13.3 transformers-4.28.1

# %%
# # Define the target directory
# TARGET_DIR = "/content/FluentSpeechCommands"  # Change this to your desired directory
# DATASET_URL = "https://zenodo.org/record/4051654/files/fluent_speech_commands_dataset.zip"

# # Create the directory if it doesn't exist
# import os
# os.makedirs(TARGET_DIR, exist_ok=True)

# # Download and extract the dataset
# !wget -O "$TARGET_DIR/fluent_speech_commands_dataset.zip" "$DATASET_URL"
# !unzip -q "$TARGET_DIR/fluent_speech_commands_dataset.zip" -d "$TARGET_DIR"
# !rm "$TARGET_DIR/fluent_speech_commands_dataset.zip"

# # Verify the dataset structure
# !ls "$TARGET_DIR"

# %%
# !pip install s3prl

# %%
# from s3prl.dataio.corpus.fluent_speech_commands import FluentSpeechCommands

# # Specify the target directory where the dataset will be saved
# target_directory = "/content/Audio_Project/dataset/FSC"

# # Download and unzip the dataset
# FluentSpeechCommands.download_dataset(target_directory)

# print(f"Dataset downloaded and saved at {target_directory}")

# %%
import torch
import torchaudio
from torchaudio.datasets import FluentSpeechCommands

# %%
dataset = FluentSpeechCommands(root="/content/Audio_Project/dataset/FSC", subset="train")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-649fa19b7d9e> in <cell line: 0>()
# ----> 1 dataset = FluentSpeechCommands(root="/content/Audio_Project/dataset/FSC", subset="train")
#
# /usr/local/lib/python3.11/dist-packages/torchaudio/datasets/fluentcommands.py in __init__(self, root, subset)
#      29
#      30         if not os.path.isdir(self._path):
# ---> 31             raise RuntimeError("Dataset not found.")
#      32
#      33         subset_path = os.path.join(self._path, "data", f"{subset}_data.csv")
#
# RuntimeError: Dataset not found.

# %%
# !wget http://140.112.21.28:9000/fluent.tar.gz -O - | tar -xz

# %%
# !git clone -b fix_error_on_download https://github.com/omertalmi5/s3prl.git

# %%
# %cd s3prl

# %%
# from pathlib import Path  # Explicitly import Path

# # Set target directory
# target_directory = Path("/content/Audio_Project/dataset/FSC")

# # Ensure the directory exists before downloading
# target_directory.mkdir(parents=True, exist_ok=True)  # Correct syntax

# # Download the dataset
# from s3prl.dataio.corpus.fluent_speech_commands import FluentSpeechCommands
# FluentSpeechCommands.download_dataset(target_directory)  # Convert to string if needed

# print(f"Dataset downloaded and saved at {target_directory}")

# %%
# !python3 main.py --data_path TARGET_DIR --is_AST True --dataset_name 'FSC' --method 'adapter' --seq_or_par 'parallel' --reduction_rate_adapter 64 --adapter_type 'Pfeiffer' --apply_residual False --adapter_block 'conformer'

# %% [markdown]
# # ESC

# %%
# Step 1: Download the dataset using wget
# !wget -q --show-progress https://github.com/karoldvl/ESC-50/archive/master.zip -O dataset/ESC-50.zip
# Out:
# dataset/ESC-50.zip      [           <=>      ] 615.78M  14.6MB/s    in 40s

# %%
# Step 2: Unzip the dataset
# !unzip -q  dataset/ESC-50.zip -d  dataset/ESC-50

# %%
# !mv dataset/ESC-50/ESC-50-master/* dataset/ESC-50/ && rm -r dataset/ESC-50/ESC-50-master

# %%
# Step 3: List extracted files to verify
# !ls  dataset/ESC-50/
# Out:
# audio  esc50.gif  LICENSE  meta  pytest.ini  README.md	requirements.txt  tests

# %% [markdown]
# ## Conformer Adapter Pfeiffer

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'adapter' --seq_or_par 'parallel' --adapter_type 'Pfeiffer'  --adapter_block 'conformer'
# Out:
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='adapter', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# preprocessor_config.json: 100% 297/297 [00:00<00:00, 2.26MB/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 26.8k/26.8k [00:00<00:00, 24.8MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors: 100% 346M/346M [00:01<00:00, 249MB/s]
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.layernorm.weight', 'classifier.layernorm.bias']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85998770
# Number of trainable params of the model: 310706
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.072289923032125
# Train intent accuracy:  20.083333333333332
# Valid intent accuracy:  36.5
# Learning rate after initialization:  0.004995066821070678
# Trainloss at epoch 1: 1.3258068601290385
# Train intent accuracy:  60.5
# Valid intent accuracy:  67.5
# Learning rate after initialization:  0.0049802867532861925
# Trainloss at epoch 2: 0.8169281029701233
# Train intent accuracy:  74.58333333333333
# Valid intent accuracy:  64.5
# Learning rate after initialization:  0.004955718126821722
# Trainloss at epoch 3: 0.6026518726845582
# Train intent accuracy:  81.58333333333333
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.004921457902821577
# Trainloss at epoch 4: 0.41984124223391217
# Train intent accuracy:  86.58333333333333
# Valid intent accuracy:  77.0
# Learning rate after initialization:  0.004877641290737882
# Trainloss at epoch 5: 0.3272812840839227
# Train intent accuracy:  89.66666666666666
# Valid intent accuracy:  78.5
# Learning rate after initialization:  0.00482444121472063
# Trainloss at epoch 6: 0.2919876118997733
# Train intent accuracy:  91.5
# Valid intent accuracy:  79.5
# Learning rate after initialization:  0.004762067631165052
# Trainloss at epoch 7: 0.30461238404115043
# Train intent accuracy:  90.91666666666667
# Valid intent accuracy:  76.25
# Learning rate after initialization:  0.0046907667001096645
# Trainloss at epoch 8: 0.22271646802624068
# Train intent accuracy:  92.66666666666666
# Valid intent accuracy:  79.5
# Learning rate after initialization:  0.004610819813755047
# Trainloss at epoch 9: 0.203440306832393
# Train intent accuracy:  93.66666666666667
# Valid intent accuracy:  75.5
# Learning rate after initialization:  0.004522542485937378
# Trainloss at epoch 10: 0.17665460874016087
# Train intent accuracy:  95.08333333333333
# Valid intent accuracy:  80.5
# Learning rate after initialization:  0.004426283106939482
# Trainloss at epoch 11: 0.1038932814821601
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  78.0
# Learning rate after initialization:  0.004322421568553542
# Trainloss at epoch 12: 0.13747897680227955
# Train intent accuracy:  96.25
# Valid intent accuracy:  80.25
# Learning rate after initialization:  0.004211367764821735
# Trainloss at epoch 13: 0.1515918981904785
# Train intent accuracy:  95.83333333333334
# Valid intent accuracy:  78.0
# Learning rate after initialization:  0.004093559974371735
# Trainloss at epoch 14: 0.11250316818555196
# Train intent accuracy:  96.83333333333334
# Valid intent accuracy:  81.5
# Learning rate after initialization:  0.003969463130731192
# Trainloss at epoch 15: 0.11541004909900948
# Train intent accuracy:  96.5
# Valid intent accuracy:  81.75
# Learning rate after initialization:  0.0038395669874475027
# Trainloss at epoch 16: 0.09335738897013167
# Train intent accuracy:  96.83333333333334
# Valid intent accuracy:  83.25
# Learning rate after initialization:  0.0037043841852542982
# Trainloss at epoch 17: 0.10357982088811696
# Train intent accuracy:  97.66666666666667
# Valid intent accuracy:  83.75
# Learning rate after initialization:  0.0035644482289126918
# Trainloss at epoch 18: 0.09594068883607786
# Train intent accuracy:  96.83333333333334
# Valid intent accuracy:  84.75
# Learning rate after initialization:  0.003420311381711705
# Trainloss at epoch 19: 0.03791927411531409
# Train intent accuracy:  99.16666666666667
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.003272542485937376
# Trainloss at epoch 20: 0.09603057220888635
# Train intent accuracy:  96.75
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.0031217247179121453
# Trainloss at epoch 21: 0.07079117103945463
# Train intent accuracy:  98.08333333333333
# Valid intent accuracy:  81.25
# Learning rate after initialization:  0.002968453286464319
# Trainloss at epoch 22: 0.06905355252713585
# Train intent accuracy:  98.08333333333333
# Valid intent accuracy:  83.75
# Learning rate after initialization:  0.0028133330839107654
# Trainloss at epoch 23: 0.04276435367685432
# Train intent accuracy:  98.75
# Valid intent accuracy:  86.5
# Learning rate after initialization:  0.002656976298823288
# Trainloss at epoch 24: 0.039801518224800624
# Train intent accuracy:  99.0
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.0025000000000000027
# Trainloss at epoch 25: 0.04103424665518105
# Train intent accuracy:  99.0
# Valid intent accuracy:  84.75
# Learning rate after initialization:  0.0023430237011767188
# Trainloss at epoch 26: 0.03261276849002267
# Train intent accuracy:  99.16666666666667
# Valid intent accuracy:  85.5
# Learning rate after initialization:  0.002186666916089242
# Trainloss at epoch 27: 0.022246196848185112
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.002031546713535689
# Trainloss at epoch 28: 0.031675375857545686
# Train intent accuracy:  99.16666666666667
# Valid intent accuracy:  83.0
# Learning rate after initialization:  0.001878275282087863
# Trainloss at epoch 29: 0.0347032040450722
# Train intent accuracy:  99.25
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.0017274575140626318
# Trainloss at epoch 30: 0.04082841747285177
# Train intent accuracy:  98.91666666666666
# Valid intent accuracy:  84.5
# Learning rate after initialization:  0.0015796886182883056
# Trainloss at epoch 31: 0.02823103577286626
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  85.5
# Learning rate after initialization:  0.0014355517710873188
# Trainloss at epoch 32: 0.033974237509537486
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  87.25
# Learning rate after initialization:  0.0012956158147457131
# Trainloss at epoch 33: 0.02389875543769449
# Train intent accuracy:  99.5
# Valid intent accuracy:  84.75
# Learning rate after initialization:  0.0011604330125525087
# Trainloss at epoch 34: 0.012532455896531852
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.0010305368692688159
# Trainloss at epoch 35: 0.014121843373092512
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.0009064400256282742
# Trainloss at epoch 36: 0.019351974783930928
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.0007886322351782771
# Trainloss at epoch 37: 0.00877294226627176
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.75
# Learning rate after initialization:  0.0006775784314464705
# Trainloss at epoch 38: 0.012086392853913518
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.0005737168930605252
# Trainloss at epoch 39: 0.009364812485485648
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.00047745751406263066
# Trainloss at epoch 40: 0.009724342932070916
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.75
# Learning rate after initialization:  0.00038918018624496204
# Trainloss at epoch 41: 0.0027144767072362205
# Train intent accuracy:  100.0
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.00030923329989034033
# Trainloss at epoch 42: 0.014523562755590925
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.25
# Learning rate after initialization:  0.0002379323688349511
# Trainloss at epoch 43: 0.013940216188396637
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.25
# Learning rate after initialization:  0.000175558785279371
# Trainloss at epoch 44: 0.005397060574420417
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.00012235870926211593
# Trainloss at epoch 45: 0.004758395982595781
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  85.75
# Learning rate after initialization:  7.854209717842241e-05
# Trainloss at epoch 46: 0.006755865785526112
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  85.25
# Learning rate after initialization:  4.4281873178278135e-05
# Trainloss at epoch 47: 0.007436176906727875
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  86.25
# Learning rate after initialization:  1.971324671380557e-05
# Trainloss at epoch 48: 0.014382495850635071
# Train intent accuracy:  99.75
# Valid intent accuracy:  85.5
# Learning rate after initialization:  4.933178929321099e-06
# Trainloss at epoch 49: 0.010199740358317892
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.75
# Learning rate after initialization:  0.0
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.layernorm.weight', 'classifier.layernorm.bias']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85998770
# Number of trainable params of the model: 310706
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 2.9793054739634197
# Train intent accuracy:  24.25
# Valid intent accuracy:  41.5
# Learning rate after initialization:  0.004995066821070678
# Trainloss at epoch 1: 1.24364750623703
# Train intent accuracy:  62.66666666666667
# Valid intent accuracy:  56.99999999999999
# Learning rate after initialization:  0.0049802867532861925
# Trainloss at epoch 2: 0.7485108987490336
# Train intent accuracy:  78.0
# Valid intent accuracy:  70.5
# Learning rate after initialization:  0.004955718126821722
# Trainloss at epoch 3: 0.51118997524182
# Train intent accuracy:  84.08333333333333
# Valid intent accuracy:  73.25
# Learning rate after initialization:  0.004921457902821577
# Trainloss at epoch 4: 0.35340694412589074
# Train intent accuracy:  88.66666666666667
# Valid intent accuracy:  71.5
# Learning rate after initialization:  0.004877641290737882
# Trainloss at epoch 5: 0.3140222258369128
# Train intent accuracy:  90.41666666666667
# Valid intent accuracy:  80.75
# Learning rate after initialization:  0.00482444121472063
# Trainloss at epoch 6: 0.335576411485672
# Train intent accuracy:  89.83333333333333
# Valid intent accuracy:  79.0
# Learning rate after initialization:  0.004762067631165052
# Trainloss at epoch 7: 0.2003723110134403
# Train intent accuracy:  93.5
# Valid intent accuracy:  78.25
# Learning rate after initialization:  0.0046907667001096645
# Trainloss at epoch 8: 0.1145072312404712
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.0007886322351782771
# Trainloss at epoch 37: 0.0073843896567511065
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.0006775784314464705
# Trainloss at epoch 38: 0.008061142038010682
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.25
# Learning rate after initialization:  0.0005737168930605252
# Trainloss at epoch 39: 0.00869942040667714
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.75
# Learning rate after initialization:  0.00047745751406263066
# Trainloss at epoch 40: 0.00699427615889969
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.00038918018624496204
# Trainloss at epoch 41: 0.00721798072491462
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.00030923329989034033
# Trainloss at epoch 42: 0.005924928861010509
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.0002379323688349511
# Trainloss at epoch 43: 0.005088913769965681
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  87.0
# Learning rate after initialization:  0.000175558785279371
# Trainloss at epoch 44: 0.015769388839641275
# Train intent accuracy:  99.75
# Valid intent accuracy:  87.25
# Learning rate after initialization:  0.00012235870926211593
# Trainloss at epoch 45: 0.010009660196568196
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  87.0
# Learning rate after initialization:  7.854209717842241e-05
# Trainloss at epoch 46: 0.003388483722616608
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  87.25
# Learning rate after initialization:  4.4281873178278135e-05
# Trainloss at epoch 47: 0.003869075929784837
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  87.0
# Learning rate after initialization:  1.971324671380557e-05
# Trainloss at epoch 48: 0.00533946927539849
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  87.25
# Learning rate after initialization:  4.933178929321099e-06
# Trainloss at epoch 49: 0.005140083811517495
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  87.25
# Learning rate after initialization:  0.0
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.layernorm.weight', 'classifier.layernorm.bias']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85998770
# Number of trainable params of the model: 310706
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.035088720321655
# Train intent accuracy:  22.083333333333332
# Valid intent accuracy:  38.0
# Learning rate after initialization:  0.004995066821070678
# Trainloss at epoch 1: 1.5005005955696107
# Train intent accuracy:  56.41666666666667
# Valid intent accuracy:  57.99999999999999
# Learning rate after initialization:  0.0049802867532861925
# Trainloss at epoch 2: 0.8995650891462962
# Train intent accuracy:  73.66666666666667
# Valid intent accuracy:  67.0
# Learning rate after initialization:  0.004955718126821722
# Trainloss at epoch 3: 0.6230965807040533
# Train intent accuracy:  80.91666666666667
# Valid intent accuracy:  66.0
# Learning rate after initialization:  0.004921457902821577
# Trainloss at epoch 4: 0.5374861324330171
# Train intent accuracy:  83.0
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.004877641290737882
# Trainloss at epoch 5: 0.33532173881928123
# Train intent accuracy:  89.66666666666666
# Valid intent accuracy:  75.25
# Learning rate after initialization:  0.00482444121472063
# Trainloss at epoch 6: 0.25660005723436674
# Train intent accuracy:  91.66666666666666
# Valid intent accuracy:  75.25
# Learning rate after initialization:  0.004762067631165052
# Trainloss at epoch 7: 0.2543945901095867
# Train intent accuracy:  91.83333333333333
# Valid intent accuracy:  74.75
# Learning rate after initialization:  0.0046907667001096645
# Trainloss at epoch 8: 0.21345522408684095
# Train intent accuracy:  93.08333333333333
# Valid intent accuracy:  76.5
# Learning rate after initialization:  0.004610819813755047
# Trainloss at epoch 9: 0.1741710498680671
# Train intent accuracy:  94.33333333333334
# Valid intent accuracy:  77.75
# Learning rate after initialization:  0.004522542485937378
# Trainloss at epoch 10: 0.17577567390166224
# Train intent accuracy:  94.5
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.004426283106939482
# Trainloss at epoch 11: 0.14108341094727317
# Train intent accuracy:  95.75
# Valid intent accuracy:  77.25
# Learning rate after initialization:  0.004322421568553542
# Trainloss at epoch 12: 0.16123490683734418
# Train intent accuracy:  95.25
# Valid intent accuracy:  77.75
# Learning rate after initialization:  0.004211367764821735
# Trainloss at epoch 13: 0.1504113975415627
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  78.75
# Learning rate after initialization:  0.004093559974371735
# Trainloss at epoch 14: 0.13460167077059548
# Train intent accuracy:  95.66666666666667
# Valid intent accuracy:  77.25
# Learning rate after initialization:  0.003969463130731192
# Trainloss at epoch 15: 0.11054335080087185
# Train intent accuracy:  96.58333333333333
# Valid intent accuracy:  77.0
# Learning rate after initialization:  0.0038395669874475027
# Trainloss at epoch 16: 0.08427232161785166
# Train intent accuracy:  97.08333333333333
# Valid intent accuracy:  78.75
# Learning rate after initialization:  0.0037043841852542982
# Trainloss at epoch 17: 0.0868102176177005
# Train intent accuracy:  97.33333333333334
# Valid intent accuracy:  80.5
# Learning rate after initialization:  0.0035644482289126918
# Trainloss at epoch 18: 0.0692403437383473
# Train intent accuracy:  98.25
# Valid intent accuracy:  78.75
# Learning rate after initialization:  0.003420311381711705
# Trainloss at epoch 19: 0.06445907750166953
# Train intent accuracy:  98.0
# Valid intent accuracy:  77.75
# Learning rate after initialization:  0.003272542485937376
# Trainloss at epoch 20: 0.09808494610401491
# Train intent accuracy:  97.58333333333333
# Valid intent accuracy:  83.25
# Learning rate after initialization:  0.0031217247179121453
# Trainloss at epoch 21: 0.06109340704822292
# Train intent accuracy:  98.66666666666667
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.002968453286464319
# Trainloss at epoch 22: 0.0705881034458677
# Train intent accuracy:  98.41666666666666
# Valid intent accuracy:  80.25
# Learning rate after initialization:  0.0028133330839107654
# Trainloss at epoch 23: 0.05027813464713593
# Train intent accuracy:  98.83333333333333
# Valid intent accuracy:  77.0
# Learning rate after initialization:  0.002656976298823288
# Trainloss at epoch 24: 0.039747892110608515
# Train intent accuracy:  99.0
# Valid intent accuracy:  82.25
# Learning rate after initialization:  0.0025000000000000027
# Trainloss at epoch 25: 0.033286188415562114
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  82.0
# Learning rate after initialization:  0.0023430237011767188
# Trainloss at epoch 26: 0.038866752612714967
# Train intent accuracy:  99.08333333333333
# Valid intent accuracy:  80.5
# Learning rate after initialization:  0.002186666916089242
# Trainloss at epoch 27: 0.033982716378911086
# Train intent accuracy:  98.91666666666666
# Valid intent accuracy:  82.25
# Learning rate after initialization:  0.002031546713535689
# Trainloss at epoch 28: 0.019475725317994755
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  81.75
# Learning rate after initialization:  0.001878275282087863
# Trainloss at epoch 29: 0.0322595303823861
# Train intent accuracy:  99.0
# Valid intent accuracy:  84.75
# Learning rate after initialization:  0.0017274575140626318
# Trainloss at epoch 30: 0.015264880930384
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.0015796886182883056
# Trainloss at epoch 31: 0.02371368658884118
# Train intent accuracy:  99.08333333333333
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.0014355517710873188
# Trainloss at epoch 32: 0.018760908336068194
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  83.5
# Learning rate after initialization:  0.0012956158147457131
# Trainloss at epoch 33: 0.02122030754496033
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.0011604330125525087
# Trainloss at epoch 34: 0.007177255360875279
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.0010305368692688159
# Trainloss at epoch 35: 0.0060424101857158045
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.0009064400256282742
# Trainloss at epoch 36: 0.007082822229907227
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  82.75
# Learning rate after initialization:  0.0007886322351782771
# Trainloss at epoch 37: 0.0037065668093661467
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  84.5
# Learning rate after initialization:  0.0006775784314464705
# Trainloss at epoch 38: 0.016182820631656797
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  83.75
# Learning rate after initialization:  0.0005737168930605252
# Trainloss at epoch 39: 0.015849197898060084
# Train intent accuracy:  99.5
# Valid intent accuracy:  85.25
# Learning rate after initialization:  0.00047745751406263066
# Trainloss at epoch 40: 0.006704122199056049
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  87.0
# Learning rate after initialization:  0.00038918018624496204
# Trainloss at epoch 41: 0.010551165538102699
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.25
# Learning rate after initialization:  0.00030923329989034033
# Trainloss at epoch 42: 0.006842357715164932
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  85.0
# Learning rate after initialization:  0.0002379323688349511
# Trainloss at epoch 43: 0.011763671185278024
# Train intent accuracy:  99.5
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.000175558785279371
# Trainloss at epoch 44: 0.0065967973861067244
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.25
# Learning rate after initialization:  0.00012235870926211593
# Trainloss at epoch 45: 0.008484531027497723
# Train intent accuracy:  99.75
# Valid intent accuracy:  86.5
# Learning rate after initialization:  7.854209717842241e-05
# Trainloss at epoch 46: 0.009912692809399838
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  85.75
# Learning rate after initialization:  4.4281873178278135e-05
# Trainloss at epoch 47: 0.00788751500872119
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  86.0
# Learning rate after initialization:  1.971324671380557e-05
# Trainloss at epoch 48: 0.003249300323271503
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  86.0
# Learning rate after initialization:  4.933178929321099e-06
# Trainloss at epoch 49: 0.0027399704252214483
# Train intent accuracy:  100.0
# Valid intent accuracy:  86.0
# Learning rate after initialization:  0.0
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.layernorm.weight', 'classifier.layernorm.bias']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85998770
# Number of trainable params of the model: 310706
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
# ...
# Trainloss at epoch 39: 0.007863613863009959
# Train intent accuracy:  99.75
# Valid intent accuracy:  88.0
# Learning rate after initialization:  0.00047745751406263066
# Trainloss at epoch 40: 0.0033346219880816836
# Train intent accuracy:  100.0
# Valid intent accuracy:  88.5
# Learning rate after initialization:  0.00038918018624496204
# Trainloss at epoch 41: 0.0049645362969022245
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  88.5
# Learning rate after initialization:  0.00030923329989034033
# Trainloss at epoch 42: 0.011385151178304416
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.0
# Learning rate after initialization:  0.0002379323688349511
# Trainloss at epoch 43: 0.007321651860062654
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.75
# Learning rate after initialization:  0.000175558785279371
# Trainloss at epoch 44: 0.0053149066322172684
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  89.0
# Learning rate after initialization:  0.00012235870926211593
# Trainloss at epoch 45: 0.0017778856724423046
# Train intent accuracy:  100.0
# Valid intent accuracy:  88.5
# Learning rate after initialization:  7.854209717842241e-05
# Trainloss at epoch 46: 0.008098555761389434
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.5
# Learning rate after initialization:  4.4281873178278135e-05
# Trainloss at epoch 47: 0.002843935266525174
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  88.75
# Learning rate after initialization:  1.971324671380557e-05
# Trainloss at epoch 48: 0.009176122507584901
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  88.75
# Learning rate after initialization:  4.933178929321099e-06
# Trainloss at epoch 49: 0.007146026411792263
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  89.0
# Learning rate after initialization:  0.0
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.layernorm.weight', 'classifier.layernorm.bias']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85998770
# Number of trainable params of the model: 310706
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.0082370694478353
# Train intent accuracy:  24.75
# Valid intent accuracy:  42.0
# Learning rate after initialization:  0.004995066821070678
# Trainloss at epoch 1: 1.391091123421987
# Train intent accuracy:  59.166666666666664
# Valid intent accuracy:  58.5
# Learning rate after initialization:  0.0049802867532861925
# Trainloss at epoch 2: 0.8174475640058517
# Train intent accuracy:  74.25
# Valid intent accuracy:  67.0
# Learning rate after initialization:  0.004955718126821722
# Trainloss at epoch 3: 0.6031990344325702
# Train intent accuracy:  81.16666666666667
# Valid intent accuracy:  70.75
# Learning rate after initialization:  0.004921457902821577
# Trainloss at epoch 4: 0.3958806436012189
# Train intent accuracy:  87.5
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.004877641290737882
# Trainloss at epoch 5: 0.35596731970707574
# Train intent accuracy:  89.25
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.00482444121472063
# Trainloss at epoch 6: 0.29803974941372874
# Train intent accuracy:  90.33333333333333
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.004762067631165052
# Trainloss at epoch 7: 0.2669011063625415
# Train intent accuracy:  91.66666666666666
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.0046907667001096645
# Trainloss at epoch 8: 0.20440330408513546
# Train intent accuracy:  94.25
# Valid intent accuracy:  76.0
# Learning rate after initialization:  0.004610819813755047
# Trainloss at epoch 9: 0.15818190151204667
# Train intent accuracy:  95.25
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.004522542485937378
# Trainloss at epoch 10: 0.23308111646523078
# Train intent accuracy:  93.08333333333333
# Valid intent accuracy:  79.25
# Learning rate after initialization:  0.004426283106939482
# Trainloss at epoch 11: 0.1362807937261338
# Train intent accuracy:  95.66666666666667
# Valid intent accuracy:  73.75
# Learning rate after initialization:  0.004322421568553542
# Trainloss at epoch 12: 0.1667787659416596
# Train intent accuracy:  95.16666666666667
# Valid intent accuracy:  78.75
# Learning rate after initialization:  0.004211367764821735
# Trainloss at epoch 13: 0.14178032487941286
# Train intent accuracy:  95.16666666666667
# Valid intent accuracy:  78.25
# Learning rate after initialization:  0.004093559974371735
# Trainloss at epoch 14: 0.07895402735099197
# Train intent accuracy:  97.5
# Valid intent accuracy:  77.0
# Learning rate after initialization:  0.003969463130731192
# Trainloss at epoch 15: 0.12028683837968857
# Train intent accuracy:  96.08333333333333
# Valid intent accuracy:  73.5
# Learning rate after initialization:  0.0038395669874475027
# Trainloss at epoch 16: 0.10309189793653786
# Train intent accuracy:  97.08333333333333
# Valid intent accuracy:  81.0
# Learning rate after initialization:  0.0037043841852542982
# Trainloss at epoch 17: 0.10770336028498907
# Train intent accuracy:  96.91666666666666
# Valid intent accuracy:  82.5
# Learning rate after initialization:  0.0035644482289126918
# Trainloss at epoch 18: 0.07731770286491761
# Train intent accuracy:  97.33333333333334
# Valid intent accuracy:  78.25
# Learning rate after initialization:  0.003420311381711705
# Trainloss at epoch 19: 0.09144711455019812
# Train intent accuracy:  97.25
# Valid intent accuracy:  77.75
# Learning rate after initialization:  0.003272542485937376
# Trainloss at epoch 20: 0.08260966839268803
# Train intent accuracy:  97.75
# Valid intent accuracy:  80.75
# Learning rate after initialization:  0.0031217247179121453
# Trainloss at epoch 21: 0.07410842536017298
# Train intent accuracy:  97.83333333333334
# Valid intent accuracy:  77.5
# Learning rate after initialization:  0.002968453286464319
# Trainloss at epoch 22: 0.06788381838860612
# Train intent accuracy:  97.83333333333334
# Valid intent accuracy:  79.0
# Learning rate after initialization:  0.0028133330839107654
# Trainloss at epoch 23: 0.06544592529147243
# Train intent accuracy:  98.58333333333333
# Valid intent accuracy:  80.0
# Learning rate after initialization:  0.002656976298823288
# Trainloss at epoch 24: 0.05714375153183937
# Train intent accuracy:  98.41666666666666
# Valid intent accuracy:  81.0
# Learning rate after initialization:  0.0025000000000000027
# Trainloss at epoch 25: 0.032770651429891585
# Train intent accuracy:  99.08333333333333
# Valid intent accuracy:  81.75
# Learning rate after initialization:  0.0023430237011767188
# Trainloss at epoch 26: 0.03440662070720767
# Train intent accuracy:  99.25
# Valid intent accuracy:  83.25
# Learning rate after initialization:  0.002186666916089242
# Trainloss at epoch 27: 0.024353727366154394
# Train intent accuracy:  99.5
# Valid intent accuracy:  81.25
# Learning rate after initialization:  0.002031546713535689
# Trainloss at epoch 28: 0.02244816965190694
# Train intent accuracy:  99.5
# Valid intent accuracy:  83.0
# Learning rate after initialization:  0.001878275282087863
# Trainloss at epoch 29: 0.009951982262621945
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  82.5
# Learning rate after initialization:  0.0017274575140626318
# Trainloss at epoch 30: 0.027107152418854336
# Train intent accuracy:  99.0
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.0015796886182883056
# Trainloss at epoch 31: 0.015093197252911826
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  83.25
# Learning rate after initialization:  0.0014355517710873188
# Trainloss at epoch 32: 0.01737892929619799
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  82.5
# Learning rate after initialization:  0.0012956158147457131
# Trainloss at epoch 33: 0.016814439779845997
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  82.0
# Learning rate after initialization:  0.0011604330125525087
# Trainloss at epoch 34: 0.0192041557864286
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.0010305368692688159
# Trainloss at epoch 35: 0.00617181347120398
# Train intent accuracy:  100.0
# Valid intent accuracy:  83.5
# Learning rate after initialization:  0.0009064400256282742
# Trainloss at epoch 36: 0.00993955934070982
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  81.75
# Learning rate after initialization:  0.0007886322351782771
# Trainloss at epoch 37: 0.006242234282932865
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  82.5
# Learning rate after initialization:  0.0006775784314464705
# Trainloss at epoch 38: 0.009008273395399252
# Train intent accuracy:  99.75
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.0005737168930605252
# Trainloss at epoch 39: 0.012986079837040355
# Train intent accuracy:  99.75
# Valid intent accuracy:  85.0
# Learning rate after initialization:  0.00047745751406263066
# Trainloss at epoch 40: 0.0022768521522327015
# Train intent accuracy:  100.0
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.00038918018624496204
# Trainloss at epoch 41: 0.001582941176990668
# Train intent accuracy:  100.0
# Valid intent accuracy:  84.25
# Learning rate after initialization:  0.00030923329989034033
# Trainloss at epoch 42: 0.008921343597661084
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  83.5
# Learning rate after initialization:  0.0002379323688349511
# Trainloss at epoch 43: 0.00463466363629171
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.000175558785279371
# Trainloss at epoch 44: 0.010775645213628499
# Train intent accuracy:  99.75
# Valid intent accuracy:  84.0
# Learning rate after initialization:  0.00012235870926211593
# Trainloss at epoch 45: 0.01642303653449441
# Train intent accuracy:  99.75
# Valid intent accuracy:  83.25
# Learning rate after initialization:  7.854209717842241e-05
# Trainloss at epoch 46: 0.0029640698853957777
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  83.25
# Learning rate after initialization:  4.4281873178278135e-05
# Trainloss at epoch 47: 0.004198258739585678
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  83.5
# Learning rate after initialization:  1.971324671380557e-05
# Trainloss at epoch 48: 0.009348841276951134
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  84.0
# Learning rate after initialization:  4.933178929321099e-06
# Trainloss at epoch 49: 0.004536081108963117
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  83.5
# Learning rate after initialization:  0.0
# Folds accuracy:  [0.865, 0.8825, 0.8825, 0.88, 0.855]
# Avg accuracy over the 5 fold(s):  0.873
# Std accuracy over the 5 fold(s):  0.011113055385446425
# Training time 1:48:53

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# ## Linear

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'linear'
# Out:
# 2025-03-14 09:18:01.960247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741943881.981043   22623 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741943881.987460   22623 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 09:18:02.007734: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='linear', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.5218912676761023
# Train intent accuracy:  15.166666666666668
# Valid intent accuracy:  36.25
# Learning rate after initialization:  0.000999013364214136

# %% [markdown]
# ## Pref-T 24

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'prefix-tuning'
# Out:
# 2025-03-14 16:30:56.931654: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741969856.952067     786 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741969856.958234     786 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 16:30:56.978803: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='prefix-tuning', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# preprocessor_config.json: 100% 297/297 [00:00<00:00, 1.93MB/s]
# config.json: 100% 26.8k/26.8k [00:00<00:00, 96.1MB/s]
# model.safetensors: 100% 346M/346M [00:00<00:00, 364MB/s]
# Some weights of ASTModel_PT were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized: ['audio_spectrogram_transformer.encoder.layer.0.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.0.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.1.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.1.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.10.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.10.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.11.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.11.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.2.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.2.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.3.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.3.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.4.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.4.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.5.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.5.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.6.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.6.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.7.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.7.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.8.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.8.attention.attention.value_tokens', 'audio_spectrogram_transformer.encoder.layer.9.attention.attention.key_tokens', 'audio_spectrogram_transformer.encoder.layer.9.attention.attention.value_tokens']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ASTModel_PT were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85967666
# Number of trainable params of the model: 261170
# AST_Prefix_tuning(
#   (model): ASTModel_PT(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_PT(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_PT(
#           (attention): ASTAttention_PT(
#             (attention): ASTSelfAttention_PT(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_PT(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_PT(
#         (attention): ASTAttention_PT(
#           (attention): ASTSelfAttention_PT(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.1750544435099552
# Train intent accuracy:  35.083333333333336
# Valid intent accuracy:  57.49999999999999
# Learning rate after initialization:  0.009990133642141356
# Traceback (most recent call last):
#   File "/content/Audio_Project/main.py", line 364, in <module>
#     main(args)
#   File "/content/Audio_Project/main.py", line 314, in main
#     train_loss, train_acc= train_one_epoch(model, train_loader, optimizer, scheduler, device, criterion)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Audio_Project/utils/engine.py", line 31, in train_one_epoch
#     loss_batch.backward()
#   File "/usr/local/lib/python3.11/dist-packages/torch/_tensor.py", line 581, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 522.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 18.12 MiB is free. Process 7981 has 14.72 GiB memory in use. Of the allocated memory 13.00 GiB is allocated by PyTorch, and 1.59 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## LoRA

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'LoRA'
# Out:
# Traceback (most recent call last):
#   File "/content/Audio_Project/main.py", line 11, in <module>
#     from src.AST import AST
#   File "/content/Audio_Project/src/AST.py", line 9, in <module>
#     from transformers import ASTModel
#   File "/usr/local/lib/python3.11/dist-packages/transformers/__init__.py", line 26, in <module>
#     from . import dependency_versions_check
#   File "/usr/local/lib/python3.11/dist-packages/transformers/dependency_versions_check.py", line 17, in <module>
#     from .utils.versions import require_version, require_version_core
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/__init__.py", line 30, in <module>
#     from .generic import (
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py", line 29, in <module>
#     from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py", line 32, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/logging.py", line 35, in <module>
#     import huggingface_hub.utils as hf_hub_utils
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/__init__.py", line 18, in <module>
#     from huggingface_hub.errors import (
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/errors.py", line 6, in <module>
#     from requests import HTTPError, Response
#   File "/usr/local/lib/python3.11/dist-packages/requests/__init__.py", line 43, in <module>
#     import urllib3
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/__init__.py", line 15, in <module>
#     from ._base_connection import _TYPE_BODY
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/_base_connection.py", line 5, in <module>
#     from .util.connection import _TYPE_SOCKET_OPTIONS
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/__init__.py", line 8, in <module>
#     from .ssl_ import (
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/ssl_.py", line 13, in <module>
#     from .url import _BRACELESS_IPV6_ADDRZ_RE, _IPV4_RE
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/url.py", line 60, in <module>
#     _IPV6_ADDRZ_RE = re.compile("^" + _IPV6_ADDRZ_PAT + "$")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/__init__.py", line 227, in compile
#     return _compile(pattern, flags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/__init__.py", line 294, in _compile
#     p = _compiler.compile(pattern, flags)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/re/_compiler.py", line 761, in compile
#     return _sre.compile(
#            ^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %% [markdown]
# #Urban

# %%
# !wget https://zenodo.org/record/1203745/files/UrbanSound8K.tar.gz?download=1 -O dataset/UrbanSound8K.tar.gz
# Out:
# --2025-04-10 11:53:01--  https://zenodo.org/record/1203745/files/UrbanSound8K.tar.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.45.92, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1203745/files/UrbanSound8K.tar.gz [following]
# --2025-04-10 11:53:02--  https://zenodo.org/records/1203745/files/UrbanSound8K.tar.gz
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6023741708 (5.6G) [application/octet-stream]
# Saving to: ‘dataset/UrbanSound8K.tar.gz’
#
# dataset/UrbanSound8  23%[===>                ]   1.34G  24.4MB/s    in 7m 30s
#
# 2025-04-10 12:00:32 (3.06 MB/s) - Connection closed at byte 1443717276. Retrying.
#
# --2025-04-10 12:00:33--  (try: 2)  https://zenodo.org/records/1203745/files/UrbanSound8K.tar.gz
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 206 PARTIAL_CONTENT
# Length: 6023741708 (5.6G), 4580024432 (4.3G) remaining [application/octet-stream]
# Saving to: ‘dataset/UrbanSound8K.tar.gz’
#
# dataset/UrbanSound8 100%[++++===============>]   5.61G  16.3MB/s    in 4m 34s
#
# 2025-04-10 12:05:07 (16.0 MB/s) - ‘dataset/UrbanSound8K.tar.gz’ saved [6023741708/6023741708]

# %%
# !tar -xzf dataset/UrbanSound8K.tar.gz -C dataset/

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'urbansound8k' --method 'full-FT'
# Out:
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='urbansound8k', method='full-FT', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel: ['classifier.dense.bias', 'classifier.layernorm.weight', 'classifier.layernorm.bias', 'classifier.dense.weight']
# - This IS expected if you are initializing ASTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 470, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85623562
# Number of trainable params of the model: 85623562
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=10, bias=True)
# )
# Start training for 30 epochs
# Trainloss at epoch 0: 0.5544487563421882
# Train intent accuracy:  81.65927802406586
# Valid intent accuracy:  87.09677419354838
# Learning rate after initialization:  4.986304738420691e-05
# Trainloss at epoch 1: 0.26330039603258615
# Train intent accuracy:  91.48828372387587
# Valid intent accuracy:  82.55675029868577
# Learning rate after initialization:  4.9453690018345294e-05
# Trainloss at epoch 2: 0.19432148517595854
# Train intent accuracy:  93.80620645978468
# Valid intent accuracy:  80.76463560334528
# Learning rate after initialization:  4.8776412907379005e-05
# Trainloss at epoch 3: 0.15145928384585358
# Train intent accuracy:  95.2374920835972
# Valid intent accuracy:  80.28673835125448
# Learning rate after initialization:  4.7838636441065205e-05
# Trainloss at epoch 4: 0.11832820870623705
# Train intent accuracy:  96.23812539582013
# Valid intent accuracy:  88.7694145758662
# Valid intent accuracy:  83.87096774193549
# Learning rate after initialization:  4.774575140626321e-06
# Trainloss at epoch 24: 0.004834262014595113
# Train intent accuracy:  99.8606713109563
# Valid intent accuracy:  84.22939068100358
# Learning rate after initialization:  3.34936490538903e-06
# Trainloss at epoch 25: 0.003724867638734008
# Train intent accuracy:  99.87333755541482
# Valid intent accuracy:  83.63201911589009
# Learning rate after initialization:  2.16136355893498e-06
# Trainloss at epoch 26: 0.004378038811785659
# Train intent accuracy:  99.84800506649778
# Valid intent accuracy:  84.46833930704899
# Learning rate after initialization:  1.2235870926211617e-06
# Trainloss at epoch 27: 0.001975343937225291
# Train intent accuracy:  99.91133628879038
# Valid intent accuracy:  84.46833930704899
# Learning rate after initialization:  5.463099816548573e-07
# Trainloss at epoch 28: 0.004422713440313004
# Train intent accuracy:  99.81000633312223
# Valid intent accuracy:  84.46833930704899
# Learning rate after initialization:  1.3695261579316724e-07
# Trainloss at epoch 29: 0.004174543351754352
# Train intent accuracy:  99.88600379987334
# Valid intent accuracy:  84.46833930704899
# Learning rate after initialization:  0.0
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel: ['classifier.dense.bias', 'classifier.layernorm.weight', 'classifier.layernorm.bias', 'classifier.dense.weight']
# - This IS expected if you are initializing ASTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 470, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85623562
# Number of trainable params of the model: 85623562
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=10, bias=True)
# )
# Start training for 30 epochs
# Trainloss at epoch 0: 0.5595284643302846
# Train intent accuracy:  81.995164779234
# Valid intent accuracy:  72.85223367697594
# Learning rate after initialization:  4.9863047384206815e-05
# Trainloss at epoch 1: 0.26481664418507883
# Train intent accuracy:  91.70377910675658
# Valid intent accuracy:  71.1340206185567
# Learning rate after initialization:  4.9453690018345185e-05
# Trainloss at epoch 2: 0.1834853050394582
# Train intent accuracy:  94.28680493701489
# Valid intent accuracy:  73.99770904925545
# Learning rate after initialization:  4.8776412907378775e-05
# Trainloss at epoch 3: 0.13744044027147376
# Train intent accuracy:  95.62285278025195
# Valid intent accuracy:  76.05956471935853
# Learning rate after initialization:  4.78386364410649e-05
# Trainloss at epoch 4: 0.11707544308255154
# Train intent accuracy:  96.27179030410994
# Valid intent accuracy:  75.83046964490264
# Learning rate after initialization:  4.6650635094610944e-05
# Trainloss at epoch 5: 0.10031943328274467
# Train intent accuracy:  96.88255503244687
# Valid intent accuracy:  74.3413516609393
# Learning rate after initialization:  4.522542485937368e-05
# Trainloss at epoch 6: 0.07970897861088179
# Train intent accuracy:  97.26428298765745
# Valid intent accuracy:  74.1122565864834
# Learning rate after initialization:  4.357862063693488e-05
# Trainloss at epoch 7: 0.07274690853724988
# Train intent accuracy:  97.68418373838911
# Valid intent accuracy:  75.25773195876289
# Learning rate after initialization:  4.172826515897139e-05
# Trainloss at epoch 8: 0.07609943763020603
# Train intent accuracy:  97.607838147347
# Valid intent accuracy:  73.6540664375716
# Learning rate after initialization:  3.9694631307311735e-05
# Trainloss at epoch 9: 0.05508363774193951
# Train intent accuracy:  98.3331212622471
# Valid intent accuracy:  76.40320733104238
# Learning rate after initialization:  3.749999999999988e-05
# Trainloss at epoch 10: 0.049835182788021806
# Train intent accuracy:  98.49853670950502
# Valid intent accuracy:  76.74684994272624
# Learning rate after initialization:  3.516841607689491e-05
# Trainloss at epoch 11: 0.039801829587969864
# Train intent accuracy:  98.70212495228401
# Valid intent accuracy:  77.31958762886599
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel: ['classifier.dense.bias', 'classifier.layernorm.weight', 'classifier.layernorm.bias', 'classifier.dense.weight']
# - This IS expected if you are initializing ASTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 470, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85623562
# Number of trainable params of the model: 85623562
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=10, bias=True)
# )
# Start training for 30 epochs
# Trainloss at epoch 0: 0.5422190502968801
# Train intent accuracy:  82.27944926058134
# Valid intent accuracy:  86.82432432432432
# Learning rate after initialization:  4.9863047384206856e-05
# Trainloss at epoch 1: 0.27069312125508904
# Train intent accuracy:  91.42019377868435
# Valid intent accuracy:  80.2927927927928
# Learning rate after initialization:  4.9453690018345314e-05
# Trainloss at epoch 2: 0.19356364219225639
# Train intent accuracy:  93.9826619071902
# Valid intent accuracy:  74.77477477477478
# Learning rate after initialization:  4.8776412907379e-05
# Trainloss at epoch 3: 0.13837080589797188
# Train intent accuracy:  95.6272310045895
# Valid intent accuracy:  85.47297297297297
# Learning rate after initialization:  4.783863644106511e-05
# Trainloss at epoch 4: 0.12871446866148992
# Train intent accuracy:  95.92044875063743
# Valid intent accuracy:  85.6981981981982
# Learning rate after initialization:  4.66506350946109e-05
# Trainloss at epoch 5: 0.10411047857409332
# Train intent accuracy:  96.77460479347272
# Valid intent accuracy:  81.08108108108108
# Learning rate after initialization:  4.522542485937359e-05
# Trainloss at epoch 6: 0.08501633551790211
# Train intent accuracy:  97.51402345741968
# Valid intent accuracy:  79.84234234234235
# Learning rate after initialization:  4.357862063693479e-05
# Trainloss at epoch 7: 0.07315845150586958
# Train intent accuracy:  97.90922998470168
# Valid intent accuracy:  87.38738738738738
# Learning rate after initialization:  4.172826515897144e-05
# Trainloss at epoch 8: 0.06005593079918533
# Train intent accuracy:  98.02396736359
# Valid intent accuracy:  84.68468468468468
# Learning rate after initialization:  3.969463130731177e-05
# Trainloss at epoch 9: 0.05956991527847426
# Train intent accuracy:  98.13870474247832
# Valid intent accuracy:  84.23423423423422
# Learning rate after initialization:  3.750000000000002e-05
# Trainloss at epoch 10: 0.048591761032423825
# Train intent accuracy:  98.5084140744518
# Valid intent accuracy:  86.48648648648648
# Learning rate after initialization:  3.516841607689503e-05
# Trainloss at epoch 11: 0.04283684305095386
# Train intent accuracy:  98.69964303926568
# Valid intent accuracy:  86.82432432432432
# Learning rate after initialization:  3.27254248593737e-05
# Trainloss at epoch 12: 0.037967601433035236
# Train intent accuracy:  98.82712901580825
# Valid intent accuracy:  79.84234234234235
# Learning rate after initialization:  3.0197792270444002e-05
# Trainloss at epoch 13: 0.027147527194578726
# Train intent accuracy:  99.15859255481897
# Valid intent accuracy:  83.8963963963964
# Learning rate after initialization:  2.7613211581691378e-05
# Trainloss at epoch 14: 0.023169741450193137
# Train intent accuracy:  99.31157572667007
# Valid intent accuracy:  87.95045045045045
# Learning rate after initialization:  2.5000000000000052e-05
# Trainloss at epoch 15: 0.021531645683860956
# Train intent accuracy:  99.31157572667007
# Valid intent accuracy:  87.04954954954955
# Learning rate after initialization:  2.23867884183087e-05
# Trainloss at epoch 16: 0.02145526903842121
# Train intent accuracy:  99.36257011728709
# Valid intent accuracy:  86.37387387387388
# Learning rate after initialization:  1.9802207729556014e-05
# Trainloss at epoch 17: 0.010519026112717827
# Train intent accuracy:  99.66853646098929
# Valid intent accuracy:  88.17567567567568
# Learning rate after initialization:  1.7274575140626376e-05
# Trainloss at epoch 18: 0.009345965148477003
# Train intent accuracy:  99.73227944926059
# Valid intent accuracy:  89.1891891891892
# Learning rate after initialization:  1.4831583923105068e-05
# Trainloss at epoch 19: 0.010832357048933247
# Train intent accuracy:  99.61754207037225
# Valid intent accuracy:  86.82432432432432
# Learning rate after initialization:  1.2500000000000051e-05
# Trainloss at epoch 20: 0.007705687405488933
# Train intent accuracy:  99.80877103518613
# Valid intent accuracy:  86.93693693693693
# Learning rate after initialization:  1.0305368692688218e-05
# Trainloss at epoch 21: 0.008980223550357205
# Train intent accuracy:  99.79602243753187
# Valid intent accuracy:  87.83783783783784
# Learning rate after initialization:  8.271734841028572e-06
# Trainloss at epoch 22: 0.005193249637401825
# Train intent accuracy:  99.83426823049464
# Valid intent accuracy:  88.62612612612612
# Learning rate after initialization:  6.421379363065164e-06
# Trainloss at epoch 23: 0.00883262321063506
# Train intent accuracy:  99.70678225395207
# Valid intent accuracy:  88.06306306306307
# Learning rate after initialization:  4.774575140626329e-06
# Trainloss at epoch 24: 0.0058738694498040415
# Train intent accuracy:  99.84701682814891
# Valid intent accuracy:  89.07657657657657
# Learning rate after initialization:  3.34936490538905e-06
# Trainloss at epoch 25: 0.0026944869292296167
# Train intent accuracy:  99.9107598164202
# Valid intent accuracy:  89.75225225225225
# Learning rate after initialization:  2.161363558934986e-06
# Trainloss at epoch 26: 0.003379262603130066
# Train intent accuracy:  99.89801121876593
# Valid intent accuracy:  89.63963963963964
# Learning rate after initialization:  1.2235870926211648e-06
# Trainloss at epoch 27: 0.0033333698553871466
# Train intent accuracy:  99.89801121876593
# Valid intent accuracy:  89.63963963963964
# Learning rate after initialization:  5.463099816548589e-07
# Trainloss at epoch 28: 0.002072108634018265
# Train intent accuracy:  99.94900560938297
# Valid intent accuracy:  89.63963963963964
# Learning rate after initialization:  1.369526157931653e-07
# Trainloss at epoch 29: 0.0035952156442803905
# Train intent accuracy:  99.9107598164202
# Valid intent accuracy:  89.63963963963964
# Learning rate after initialization:  0.0
# Folds accuracy:  [0.8446833930704899, 0.7514318442153494, 0.8963963963963963]
# Avg accuracy over the 3 fold(s):  0.8308372112274118
# Std accuracy over the 3 fold(s):  0.059985931189385625
# Training time 3:58:23

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'urbansound8k' --method 'adapter' --seq_or_par 'parallel' --adapter_type 'Pfeiffer'  --adapter_block 'conformer'
# Out:
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='urbansound8k', method='adapter', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.layernorm.bias', 'classifier.layernorm.weight']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 470, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85875850
# Number of trainable params of the model: 279946
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features
# Trainloss at epoch 27: 0.025280622646078416
# Train intent accuracy:  99.33833821096832
# Valid intent accuracy:  70.44673539518901
# Learning rate after initialization:  5.4630998165485715e-05
# Trainloss at epoch 28: 0.02337989526977327
# Train intent accuracy:  99.27471688509989
# Valid intent accuracy:  71.3631156930126
# Learning rate after initialization:  1.3695261579316672e-05
# Trainloss at epoch 29: 0.020020002395200222
# Train intent accuracy:  99.46558086270518
# Valid intent accuracy:  71.47766323024055
# Learning rate after initialization:  0.0
# Some weights of the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 were not used when initializing ASTModel_adapter: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.layernorm.bias', 'classifier.layernorm.weight']
# - This IS expected if you are initializing ASTModel_adapter from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ASTModel_adapter from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 470, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85875850
# Number of trainable params of the model: 279946
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTAttention(
#             (attention): ASTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#             (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 16, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(8, 8, kernel_size=(31,), stride=(1,), padding=same, groups=8)
#           (bnorm): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(8, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=10, bias=True)
# )
# Start training for 30 epochs
# Trainloss at epoch 0: 0.8230814463070114
# Train intent accuracy:  72.74349821519634
# Valid intent accuracy:  73.98648648648648
# Learning rate after initialization:  0.004986304738420683
# Trainloss at epoch 1: 0.4148298158156714
# Train intent accuracy:  86.37174910759816
# Valid intent accuracy:  73.1981981981982
# Learning rate after initialization:  0.004945369001834528
# Trainloss at epoch 2: 0.3367375264801616
# Train intent accuracy:  88.98521162672107
# Valid intent accuracy:  80.2927927927928
# Learning rate after initialization:  0.004877641290737902
# Trainloss at epoch 3: 0.2913793929702699
# Train intent accuracy:  90.36206017338093
# Valid intent accuracy:  84.12162162162163
# Learning rate after initialization:  0.004783863644106522
# Trainloss at epoch 4: 0.2810369453614847
# Train intent accuracy:  90.57878633350332
# Valid intent accuracy:  78.94144144144144
# Learning rate after initialization:  0.0046650635094611145
# Trainloss at epoch 5: 0.2682515863355727
# Train intent accuracy:  91.1907190209077
# Valid intent accuracy:  79.72972972972973
# Learning rate after initialization:  0.004522542485937386
# Trainloss at epoch 6: 0.25011164491309534
# Train intent accuracy:  91.72616012238653
# Valid intent accuracy:  73.87387387387388
# Learning rate after initialization:  0.004357862063693506
# Trainloss at epoch 7: 0.2322561059037106
# Train intent accuracy:  92.63131055583885
# Valid intent accuracy:  81.64414414414415
# Learning rate after initialization:  0.004172826515897175
# Trainloss at epoch 8: 0.22528424766104357
# Train intent accuracy:  92.45283018867924
# Valid intent accuracy:  77.81531531531532
# Learning rate after initialization:  0.00396946313073121
# Trainloss at epoch 9: 0.21470684005381907
# Train intent accuracy:  92.64405915349312
# Valid intent accuracy:  80.96846846846847
# Learning rate after initialization:  0.0037500000000000263
# Trainloss at epoch 10: 0.20580035015322312
# Train intent accuracy:  93.06476287608363
# Valid intent accuracy:  83.67117117117117
# Learning rate after initialization:  0.0035168416076895243
# Trainloss at epoch 11: 0.18286108469273782
# Train intent accuracy:  93.79143294237635
# Valid intent accuracy:  78.94144144144144
# Learning rate after initialization:  0.0032725424859373895
# Trainloss at epoch 12: 0.17194773278354672
# Train intent accuracy:  94.40336562978072
# Valid intent accuracy:  77.02702702702703
# Learning rate after initialization:  0.0030197792270444147
# Trainloss at epoch 13: 0.17126606742077546
# Train intent accuracy:  94.4416114227435
# Valid intent accuracy:  86.71171171171171
# Learning rate after initialization:  0.002761321158169152
# Trainloss at epoch 14: 0.15551477914596404
# Train intent accuracy:  95.01529831718511
# Valid intent accuracy:  83.22072072072072
# Learning rate after initialization:  0.002500000000000012
# Trainloss at epoch 15: 0.154746780888976
# Train intent accuracy:  95.00254971953085
# Valid intent accuracy:  83.1081081081081
# Learning rate after initialization:  0.0022386788418308754
# Trainloss at epoch 16: 0.1396350950351679
# Train intent accuracy:  95.72921978582356
# Valid intent accuracy:  79.5045045045045
# Learning rate after initialization:  0.001980220772955612
# Trainloss at epoch 17: 0.12187117943540215
# Train intent accuracy:  95.94594594594594
# Valid intent accuracy:  82.54504504504504
# Learning rate after initialization:  0.0017274575140626422
# Trainloss at epoch 18: 0.1083439496080742
# Train intent accuracy:  96.54513003569608
# Valid intent accuracy:  79.5045045045045
# Learning rate after initialization:  0.0014831583923105099
# Trainloss at epoch 19: 0.08651517222653468
# Train intent accuracy:  97.15706272310047
# Valid intent accuracy:  78.04054054054053
# Learning rate after initialization:  0.0012500000000000094
# Trainloss at epoch 20: 0.07465875642246125
# Train intent accuracy:  97.628760836308
# Valid intent accuracy:  87.16216216216216
# Learning rate after initialization:  0.0010305368692688282
# Trainloss at epoch 21: 0.07444604183902846
# Train intent accuracy:  97.65425803161652
# Valid intent accuracy:  84.009009009009
# Learning rate after initialization:  0.0008271734841028634
# Trainloss at epoch 22: 0.05561216255600608
# Train intent accuracy:  98.29168791432943
# Valid intent accuracy:  85.02252252252252
# Learning rate after initialization:  0.0006421379363065224
# Trainloss at epoch 23: 0.04724296535815889
# Train intent accuracy:  98.66139724630291
# Valid intent accuracy:  85.58558558558559
# Learning rate after initialization:  0.00047745751406263803
# Trainloss at epoch 24: 0.040751079010137956
# Train intent accuracy:  98.77613462519122
# Valid intent accuracy:  86.82432432432432
# Learning rate after initialization:  0.00033493649053890716
# Trainloss at epoch 25: 0.03455517117365343
# Train intent accuracy:  98.99286078531362
# Valid intent accuracy:  87.61261261261262
# Learning rate after initialization:  0.0002161363558935004
# Trainloss at epoch 26: 0.031963646461745696
# Train intent accuracy:  99.08210096889341
# Valid intent accuracy:  87.04954954954955
# Learning rate after initialization:  0.00012235870926211755
# Trainloss at epoch 27: 0.02517798870086244
# Train intent accuracy:  99.34982151963284
# Valid intent accuracy:  87.83783783783784
# Learning rate after initialization:  5.4630998165486454e-05
# Trainloss at epoch 28: 0.02432915552649903
# Train intent accuracy:  99.34982151963284
# Valid intent accuracy:  86.37387387387388
# Learning rate after initialization:  1.3695261579316642e-05
# Trainloss at epoch 29: 0.022656569142741494
# Train intent accuracy:  99.36257011728709
# Valid intent accuracy:  87.04954954954955
# Learning rate after initialization:  0.0
# Folds accuracy:  [0.8649940262843488, 0.7147766323024055, 0.8704954954954955]
# Avg accuracy over the 3 fold(s):  0.8167553846940834
# Std accuracy over the 3 fold(s):  0.07214483578373274
# Training time 3:00:46
