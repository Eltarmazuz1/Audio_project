# %%
# !git clone https://github.com/Eltarmazuz1/Audio_project.git
# Out:
# Cloning into 'Audio_Project'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 282 (delta 152), reused 251 (delta 138), pack-reused 0 (from 0)
# Receiving objects: 100% (282/282), 3.19 MiB | 37.17 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
# %cd Audio_Project
# Out:
# /content/Audio_Project

# %% [markdown]
# # fluent-speech-commands-dataset

# %%
# !pip install numpy torch torchaudio torchvision wandb transformers librosa
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.7)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.10.2.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.25.6)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.10.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.22.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
# # Define the target directory
# TARGET_DIR = "/content/FluentSpeechCommands"  # Change this to your desired directory
# DATASET_URL = "https://zenodo.org/record/4051654/files/fluent_speech_commands_dataset.zip"

# # Create the directory if it doesn't exist
# import os
# os.makedirs(TARGET_DIR, exist_ok=True)

# # Download and extract the dataset
# !wget -O "$TARGET_DIR/fluent_speech_commands_dataset.zip" "$DATASET_URL"
# !unzip -q "$TARGET_DIR/fluent_speech_commands_dataset.zip" -d "$TARGET_DIR"
# !rm "$TARGET_DIR/fluent_speech_commands_dataset.zip"

# # Verify the dataset structure
# !ls "$TARGET_DIR"

# %%
# !pip install s3prl
# Out:
# ['Collecting s3prl',
#  '  Downloading s3prl-0.4.17.tar.gz (650 kB)',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/650.4 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b645.1/650.4 kB\x1b \x1b23.0 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b650.4/650.4 kB\x1b \x1b15.4 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h  Preparing metadata (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  'Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from s3prl) (2.5.1+cu124)',
#  'Requirement already satisfied: torch!=1.10.0,>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from s3prl) (2.5.1+cu124)',
#  'Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.11/dist-packages (from s3prl) (4.67.1)',
#  'Requirement already satisfied: numpy<2.0.0,>=1.21 in /usr/local/lib/python3.11/dist-packages (from s3prl) (1.26.4)',
#  'Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from s3prl) (6.0.2)',
#  'Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from s3prl) (3.17.0)',
#  'Collecting omegaconf>=2.1.1 (from s3prl)',
#  '  Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)',
#  'Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.11/dist-packages (from s3prl) (75.1.0)',
#  'Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from s3prl) (2.32.3)',
#  'Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from s3prl) (4.48.3)',
#  'Requirement already satisfied: protobuf>=4.21.1 in /usr/local/lib/python3.11/dist-packages (from s3prl) (4.25.6)',
#  'Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.1.1->s3prl)',
#  '  Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/117.0 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b117.0/117.0 kB\x1b \x1b10.7 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h  Preparing metadata (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  'Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (4.12.2)',
#  'Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (3.4.2)',
#  'Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (3.1.5)',
#  'Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (2024.10.0)',
#  'Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.127)',
#  'Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.127)',
#  'Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.127)',
#  'Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (9.1.0.70)',
#  'Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.5.8)',
#  'Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (11.2.1.3)',
#  'Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (10.3.5.147)',
#  'Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (11.6.1.9)',
#  'Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.3.1.170)',
#  'Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (2.21.5)',
#  'Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.127)',
#  'Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (12.4.127)',
#  'Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (3.1.0)',
#  'Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch!=1.10.0,>=1.8.0->s3prl) (1.13.1)',
#  'Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch!=1.10.0,>=1.8.0->s3prl) (1.3.0)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->s3prl) (3.4.1)',
#  'Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->s3prl) (3.10)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->s3prl) (2.3.0)',
#  'Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->s3prl) (2025.1.31)',
#  'Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers->s3prl) (0.28.1)',
#  'Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers->s3prl) (24.2)',
#  'Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->s3prl) (2024.11.6)',
#  'Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->s3prl) (0.21.0)',
#  'Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->s3prl) (0.5.3)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch!=1.10.0,>=1.8.0->s3prl) (3.0.2)',
#  'Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)',
#  '\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/79.5 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b79.5/79.5 kB\x1b \x1b7.3 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25hBuilding wheels for collected packages: s3prl, antlr4-python3-runtime',
#  '  Building wheel for s3prl (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  '  Created wheel for s3prl: filename=s3prl-0.4.17-py3-none-any.whl size=879927 sha256=923a554cfa54ea493401f55489211d4b9a42ea33ebefdccc0c8b06226297fa9c',
#  '  Stored in directory: /root/.cache/pip/wheels/85/c2/15/7a02361558ab1b2eeb7528ad50661b5d130d7cf93e43c15150',
#  '  Building wheel for antlr4-python3-runtime (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  '  Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=2abcfe7d04bc44bc259fa637f3a24b71318c01096bc31acac8251d3d34576c4f',
#  '  Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1',
#  'Successfully built s3prl antlr4-python3-runtime',
#  'Installing collected packages: antlr4-python3-runtime, omegaconf, s3prl',
#  'Successfully installed antlr4-python3-runtime-4.9.3 omegaconf-2.3.0 s3prl-0.4.17']

# %%
# from s3prl.dataio.corpus.fluent_speech_commands import FluentSpeechCommands

# # Specify the target directory where the dataset will be saved
# target_directory = "/content/Audio_Project/dataset/FSC"

# # Download and unzip the dataset
# FluentSpeechCommands.download_dataset(target_directory)

# print(f"Dataset downloaded and saved at {target_directory}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d82019e25217> in <cell line: 0>()
#       5
#       6 # Download and unzip the dataset
# ----> 7 FluentSpeechCommands.download_dataset(target_directory)
#       8
#       9 print(f"Dataset downloaded and saved at {target_directory}")
#
# /usr/local/lib/python3.11/dist-packages/s3prl/dataio/corpus/fluent_speech_commands.py in download_dataset(cls, tgt_dir)
#     122
#     123         tgt_dir = Path(tgt_dir)
# --> 124         tgt_dir.mkdir(exists_ok=True, parents=True)
#     125
#     126         def unzip_targz_then_delete(filepath: str):
#
# TypeError: Path.mkdir() got an unexpected keyword argument 'exists_ok'

# %%
import torch
import torchaudio
from torchaudio.datasets import FluentSpeechCommands

# %%
dataset = FluentSpeechCommands(root="/content/Audio_Project/dataset/FSC", subset="train")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-649fa19b7d9e> in <cell line: 0>()
# ----> 1 dataset = FluentSpeechCommands(root="/content/Audio_Project/dataset/FSC", subset="train")
#
# /usr/local/lib/python3.11/dist-packages/torchaudio/datasets/fluentcommands.py in __init__(self, root, subset)
#      29
#      30         if not os.path.isdir(self._path):
# ---> 31             raise RuntimeError("Dataset not found.")
#      32
#      33         subset_path = os.path.join(self._path, "data", f"{subset}_data.csv")
#
# RuntimeError: Dataset not found.

# %%
# !wget http://140.112.21.28:9000/fluent.tar.gz -O - | tar -xz
# Out:
# --2025-03-09 18:02:27--  http://140.112.21.28:9000/fluent.tar.gz
# Connecting to 140.112.21.28:9000... failed: Connection refused.
#
# gzip: stdin: unexpected end of file
# tar: Child returned status 1
# tar: Error is not recoverable: exiting now

# %%
# !git clone -b fix_error_on_download https://github.com/omertalmi5/s3prl.git
# Out:
# Cloning into 's3prl'...
# remote: Enumerating objects: 21244, done.
# remote: Counting objects: 100% (400/400), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 21244 (delta 319), reused 240 (delta 233), pack-reused 20844 (from 4)
# Receiving objects: 100% (21244/21244), 125.64 MiB | 26.93 MiB/s, done.
# Resolving deltas: 100% (14473/14473), done.

# %%
# %cd s3prl
# Out:
# /content/s3prl

# %%
# from pathlib import Path  # Explicitly import Path

# # Set target directory
# target_directory = Path("/content/Audio_Project/dataset/FSC")

# # Ensure the directory exists before downloading
# target_directory.mkdir(parents=True, exist_ok=True)  # Correct syntax

# # Download the dataset
# from s3prl.dataio.corpus.fluent_speech_commands import FluentSpeechCommands
# FluentSpeechCommands.download_dataset(target_directory)  # Convert to string if needed

# print(f"Dataset downloaded and saved at {target_directory}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492         try:
# --> 493             conn.request(
#     494                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444             self.putheader(header, value)
# --> 445         self.endheaders()
#     446
#
# /usr/lib/python3.11/http/client.py in endheaders(self, message_body, encode_chunked)
#    1297             raise CannotSendHeader()
# -> 1298         self._send_output(message_body, encode_chunked=encode_chunked)
#    1299
#
# /usr/lib/python3.11/http/client.py in _send_output(self, message_body, encode_chunked)
#    1057         del self._buffer[:]
# -> 1058         self.send(msg)
#    1059
#
# /usr/lib/python3.11/http/client.py in send(self, data)
#     995             if self.auto_open:
# --> 996                 self.connect()
#     997             else:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in connect(self)
#     275     def connect(self) -> None:
# --> 276         self.sock = self._new_conn()
#     277         if self._tunnel_host:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _new_conn(self)
#     212         except OSError as e:
# --> 213             raise NewConnectionError(
#     214                 self, f"Failed to establish a new connection: {e}"
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7b983f0580d0>: Failed to establish a new connection: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840
# --> 841             retries = retries.increment(
#     842                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     518             reason = error or ResponseError(cause)
# --> 519             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     520
#
# MaxRetryError: HTTPConnectionPool(host='140.112.21.28', port=9000): Max retries exceeded with url: /fluent.tar.gz (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7b983f0580d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-e4f8c2a8a7cf> in <cell line: 0>()
#       9 # Download the dataset
#      10 from s3prl.dataio.corpus.fluent_speech_commands import FluentSpeechCommands
# ---> 11 FluentSpeechCommands.download_dataset(target_directory)  # Convert to string if needed
#      12
#      13 print(f"Dataset downloaded and saved at {target_directory}")
#
# /content/s3prl/s3prl/dataio/corpus/fluent_speech_commands.py in download_dataset(cls, tgt_dir)
#     160             )
#     161         ):
# --> 162             download_from_url("http://140.112.21.28:9000/fluent.tar.gz")
#     163         logger.info(
#     164             f"Fluent speech commands dataset downloaded. Located at {os.path.abspath(tgt_dir)}/fluent_speech_commands_dataset/"
#
# /content/s3prl/s3prl/dataio/corpus/fluent_speech_commands.py in download_from_url(url)
#     133             filepath = os.path.join(tgt_dir, filename)
#     134
# --> 135             r = requests.get(url, stream=True)
#     136             if r.ok:
#     137                 logger.info(f"Saving {filename} to", os.path.abspath(filepath))
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     698                 raise SSLError(e, request=request)
#     699
# --> 700             raise ConnectionError(e, request=request)
#     701
#     702         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='140.112.21.28', port=9000): Max retries exceeded with url: /fluent.tar.gz (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7b983f0580d0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
# !python3 main.py --data_path TARGET_DIR --is_AST True --dataset_name 'FSC' --method 'adapter' --seq_or_par 'parallel' --reduction_rate_adapter 64 --adapter_type 'Pfeiffer' --apply_residual False --adapter_block 'conformer'

# %% [markdown]
# # ESC

# %%
# Step 1: Download the dataset using wget
# !wget -q --show-progress https://github.com/karoldvl/ESC-50/archive/master.zip -O dataset/ESC-50.zip
# Out:
# dataset/ESC-50.zip      [        <=>         ] 615.78M  14.5MB/s    in 40s

# %%
# Step 2: Unzip the dataset
# !unzip -q  dataset/ESC-50.zip -d  dataset/ESC-50

# %%
# !mv dataset/ESC-50/ESC-50-master/* dataset/ESC-50/ && rm -r dataset/ESC-50/ESC-50-master

# %%
# Step 3: List extracted files to verify
# !ls  dataset/ESC-50/
# Out:
# audio  esc50.gif  LICENSE  meta  pytest.ini  README.md	requirements.txt  tests

# %% [markdown]
# ## Conformer Adapter Pfeiffer

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'adapter' --seq_or_par 'parallel' --reduction_rate_adapter 64 --adapter_type 'Pfeiffer' --apply_residual False --adapter_block 'conformer'
# Out:
# 2025-03-14 09:00:32.947297: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741942832.968042   17927 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741942832.974354   17927 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 09:00:32.995426: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='adapter', seq_or_par='parallel', reduction_rate_adapter=64, adapter_type='Pfeiffer', apply_residual=True, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized: ['audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogr ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 86111090
# Number of trainable params of the model: 423026
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#             (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTSdpaAttention(
#           (attention): ASTSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#           (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 2 epochs
# Trainloss at epoch 0: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  5.000000000000001e-05
# Trainloss at epoch 1: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized: ['audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogr ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 86111090
# Number of trainable params of the model: 423026
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#             (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTSdpaAttention(
#           (attention): ASTSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#           (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 2 epochs
# Trainloss at epoch 0: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  5.000000000000001e-05
# Trainloss at epoch 1: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized: ['audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogr ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 86111090
# Number of trainable params of the model: 423026
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#             (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTSdpaAttention(
#           (attention): ASTSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#           (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 2 epochs
# Trainloss at epoch 0: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  5.000000000000001e-05
# Trainloss at epoch 1: nan
# Train intent accuracy:  2.0
# Valid intent accuracy:  2.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized: ['audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.0.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.1.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.dwise_conv.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.lnorm.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv1.weight', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.bias', 'audio_spectrogram_transformer.encoder.layer.10.adapter_module_FFN.pwise_conv2.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.bias', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.num_batches_tracked', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_mean', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.running_var', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.bnorm.weight', 'audio_spectrogram_transformer.encoder.layer.11.adapter_module_FFN.dwise_conv.bias', 'audio_spectrogr ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ASTModel_adapter were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 86111090
# Number of trainable params of the model: 423026
# AST_adapter(
#   (model): ASTModel_adapter(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder_adapter(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer_adapter(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (adapter_module_FFN): Conformer_adapter(
#             (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#             (act1): GLU(dim=1)
#             (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#             (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act2): SiLU()
#             (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder_adapter(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer_adapter(
#         (attention): ASTSdpaAttention(
#           (attention): ASTSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (adapter_module_FFN): Conformer_adapter(
#           (lnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (pwise_conv1): Conv1d(768, 24, kernel_size=(1,), stride=(1,))
#           (act1): GLU(dim=1)
#           (dwise_conv): Conv1d(12, 12, kernel_size=(31,), stride=(1,), padding=same, groups=12)
#           (bnorm): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): SiLU()
#           (pwise_conv2): Conv1d(12, 768, kernel_size=(1,), stride=(1,))
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 2 epochs
# Traceback (most recent call last):
#   File "/content/Audio_Project/main.py", line 364, in <module>
#     main(args)
#   File "/content/Audio_Project/main.py", line 314, in main
#     train_loss, train_acc= train_one_epoch(model, train_loader, optimizer, scheduler, device, criterion)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Audio_Project/utils/engine.py", line 21, in train_one_epoch
#     x = x.to(device)
#         ^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	dataset/ESC-50.zip
# 	dataset/ESC-50/
# 	dataset/__pycache__/esc_50.cpython-311.pyc
# 	dataset/__pycache__/fluentspeech.cpython-311.pyc
# 	dataset/__pycache__/google_speech_commands_v2.cpython-311.pyc
# 	dataset/__pycache__/iemocap.cpython-311.pyc
# 	dataset/__pycache__/urban_sound_8k.cpython-311.pyc
# 	src/__pycache__/AST.cpython-311.pyc
# 	src/__pycache__/AST_LoRA.cpython-311.pyc
# 	src/__pycache__/AST_adapters.cpython-311.pyc
# 	src/__pycache__/AST_prompt_tuning.cpython-311.pyc
# 	src/__pycache__/MoA.cpython-311.pyc
# 	src/__pycache__/Wav2Vec_adapter.cpython-311.pyc
# 	utils/__pycache__/engine.cpython-311.pyc
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ## Linear

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'linear'
# Out:
# 2025-03-14 09:18:01.960247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741943881.981043   22623 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741943881.987460   22623 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 09:18:02.007734: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='linear', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.5218912676761023
# Train intent accuracy:  15.166666666666668
# Valid intent accuracy:  36.25
# Learning rate after initialization:  0.000999013364214136
# Trainloss at epoch 1: 2.4698331105081657
# Train intent accuracy:  46.833333333333336
# Valid intent accuracy:  50.5
# Learning rate after initialization:  0.0009960573506572399
# Trainloss at epoch 2: 1.8515445935098749
# Train intent accuracy:  65.16666666666666
# Valid intent accuracy:  57.25
# Learning rate after initialization:  0.0009911436253643446
# Trainloss at epoch 3: 1.4797502207128626
# Train intent accuracy:  70.58333333333333
# Valid intent accuracy:  60.0
# Learning rate after initialization:  0.0009842915805643158
# Trainloss at epoch 4: 1.2479573237268549
# Train intent accuracy:  72.83333333333334
# Valid intent accuracy:  64.75
# Learning rate after initialization:  0.000975528258147577
# Trainloss at epoch 5: 1.0950881634887897
# Train intent accuracy:  77.25
# Valid intent accuracy:  63.0
# Learning rate after initialization:  0.0009648882429441261
# Trainloss at epoch 6: 0.9428617389578569
# Train intent accuracy:  78.41666666666667
# Valid intent accuracy:  66.0
# Learning rate after initialization:  0.0009524135262330102
# Trainloss at epoch 7: 0.8382665373777088
# Train intent accuracy:  82.0
# Valid intent accuracy:  66.75
# Learning rate after initialization:  0.0009381533400219322
# Trainloss at epoch 8: 0.7675543349040183
# Train intent accuracy:  83.0
# Valid intent accuracy:  67.5
# Learning rate after initialization:  0.000922163962751008
# Trainloss at epoch 9: 0.6943480623395819
# Train intent accuracy:  84.08333333333333
# Valid intent accuracy:  70.0
# Learning rate after initialization:  0.0009045084971874742
# Trainloss at epoch 10: 0.6299107843323758
# Train intent accuracy:  86.25
# Valid intent accuracy:  68.75
# Learning rate after initialization:  0.0008852566213878953
# Trainloss at epoch 11: 0.5859120958729794
# Train intent accuracy:  86.83333333333333
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.0008644843137107065
# Trainloss at epoch 12: 0.5537487401774055
# Train intent accuracy:  86.66666666666667
# Valid intent accuracy:  70.5
# Learning rate after initialization:  0.0008422735529643454
# Trainloss at epoch 13: 0.5161820720685156
# Train intent accuracy:  89.08333333333334
# Valid intent accuracy:  70.0
# Learning rate after initialization:  0.0008187119948743456
# Trainloss at epoch 14: 0.49283479938381597
# Train intent accuracy:  88.0
# Valid intent accuracy:  70.0
# Learning rate after initialization:  0.0007938926261462369
# Trainloss at epoch 15: 0.47404080315640096
# Train intent accuracy:  89.25
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.000767913397489498
# Trainloss at epoch 16: 0.44950835838129644
# Train intent accuracy:  90.66666666666666
# Valid intent accuracy:  70.5
# Learning rate after initialization:  0.0007408768370508574
# Trainloss at epoch 17: 0.43687596603443746
# Train intent accuracy:  90.0
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.0007128896457825359
# Trainloss at epoch 18: 0.3983646517521457
# Train intent accuracy:  91.83333333333333
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.0006840622763423389
# Trainloss at epoch 19: 0.37289115864979594
# Train intent accuracy:  92.5
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.0006545084971874734
# Trainloss at epoch 20: 0.35847828968575124
# Train intent accuracy:  93.16666666666666
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.0006243449435824276
# Trainloss at epoch 21: 0.35115521832516317
# Train intent accuracy:  92.25
# Valid intent accuracy:  73.0
# Learning rate after initialization:  0.0005936906572928625
# Trainloss at epoch 22: 0.3413168584045611
# Train intent accuracy:  93.16666666666666
# Valid intent accuracy:  70.5
# Learning rate after initialization:  0.000562666616782152
# Trainloss at epoch 23: 0.33189883632095235
# Train intent accuracy:  93.5
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.0005313952597646564
# Trainloss at epoch 24: 0.3116064832398766
# Train intent accuracy:  93.91666666666667
# Valid intent accuracy:  73.5
# Learning rate after initialization:  0.0004999999999999999
# Trainloss at epoch 25: 0.2938313029314342
# Train intent accuracy:  95.33333333333334
# Valid intent accuracy:  73.0
# Learning rate after initialization:  0.00046860474023534336
# Trainloss at epoch 26: 0.3030089567366399
# Train intent accuracy:  94.25
# Valid intent accuracy:  73.0
# Learning rate after initialization:  0.0004373333832178479
# Trainloss at epoch 27: 0.2951852969433132
# Train intent accuracy:  94.16666666666667
# Valid intent accuracy:  73.0
# Learning rate after initialization:  0.0004063093427071379
# Trainloss at epoch 28: 0.2734380442845194
# Train intent accuracy:  94.66666666666667
# Valid intent accuracy:  74.25
# Learning rate after initialization:  0.00037565505641757273
# Trainloss at epoch 29: 0.2704133418829818
# Train intent accuracy:  95.0
# Valid intent accuracy:  73.75
# Learning rate after initialization:  0.0003454915028125263
# Trainloss at epoch 30: 0.25913725989429576
# Train intent accuracy:  95.83333333333334
# Valid intent accuracy:  73.75
# Learning rate after initialization:  0.0003159377236576611
# Trainloss at epoch 31: 0.2606475133644907
# Train intent accuracy:  94.83333333333334
# Valid intent accuracy:  73.5
# Learning rate after initialization:  0.0002871103542174638
# Trainloss at epoch 32: 0.25726992676132604
# Train intent accuracy:  95.5
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.00025912316294914245
# Trainloss at epoch 33: 0.27229478092570053
# Train intent accuracy:  94.75
# Valid intent accuracy:  73.5
# Learning rate after initialization:  0.00023208660251050172
# Trainloss at epoch 34: 0.24486347405534042
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  74.0
# Learning rate after initialization:  0.00020610737385376345
# Trainloss at epoch 35: 0.23710269912293083
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  74.0
# Learning rate after initialization:  0.0001812880051256551
# Trainloss at epoch 36: 0.23614719196369774
# Train intent accuracy:  96.58333333333333
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.00015772644703565585
# Trainloss at epoch 37: 0.2535948741592859
# Train intent accuracy:  95.66666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.00013551568628929436
# Trainloss at epoch 38: 0.2393919809868461
# Train intent accuracy:  96.75
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.0001147433786121053
# Trainloss at epoch 39: 0.23633399958673276
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  74.0
# Learning rate after initialization:  9.549150281252633e-05
# Trainloss at epoch 40: 0.23202977603987643
# Train intent accuracy:  95.83333333333334
# Valid intent accuracy:  74.25
# Learning rate after initialization:  7.783603724899248e-05
# Trainloss at epoch 41: 0.22617569840268084
# Train intent accuracy:  96.66666666666667
# Valid intent accuracy:  74.25
# Learning rate after initialization:  6.184665997806835e-05
# Trainloss at epoch 42: 0.24167041009978243
# Train intent accuracy:  95.66666666666667
# Valid intent accuracy:  73.5
# Learning rate after initialization:  4.7586473766990335e-05
# Trainloss at epoch 43: 0.22186789171476112
# Train intent accuracy:  96.58333333333333
# Valid intent accuracy:  74.0
# Learning rate after initialization:  3.5111757055874265e-05
# Trainloss at epoch 44: 0.23029345019083275
# Train intent accuracy:  96.0
# Valid intent accuracy:  74.0
# Learning rate after initialization:  2.4471741852423238e-05
# Trainloss at epoch 45: 0.22030104402648776
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  73.75
# Learning rate after initialization:  1.5708419435684463e-05
# Trainloss at epoch 46: 0.23101917046465373
# Train intent accuracy:  96.0
# Valid intent accuracy:  73.75
# Learning rate after initialization:  8.856374635655697e-06
# Trainloss at epoch 47: 0.23458424857572505
# Train intent accuracy:  95.5
# Valid intent accuracy:  74.0
# Learning rate after initialization:  3.942649342761118e-06
# Trainloss at epoch 48: 0.240528194527877
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  74.0
# Learning rate after initialization:  9.866357858642204e-07
# Trainloss at epoch 49: 0.23718211525364927
# Train intent accuracy:  96.66666666666667
# Valid intent accuracy:  74.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.538444807654933
# Train intent accuracy:  15.833333333333332
# Valid intent accuracy:  36.75
# Learning rate after initialization:  0.000999013364214136
# Trainloss at epoch 1: 2.4903375976964046
# Train intent accuracy:  46.58333333333333
# Valid intent accuracy:  52.5
# Learning rate after initialization:  0.0009960573506572399
# Trainloss at epoch 2: 1.8556432441661233
# Train intent accuracy:  61.33333333333333
# Valid intent accuracy:  53.75
# Learning rate after initialization:  0.0009911436253643446
# Trainloss at epoch 3: 1.4751190668658207
# Train intent accuracy:  69.0
# Valid intent accuracy:  63.74999999999999
# Learning rate after initialization:  0.0009842915805643158
# Trainloss at epoch 4: 1.2106165729070966
# Train intent accuracy:  73.08333333333333
# Valid intent accuracy:  64.5
# Learning rate after initialization:  0.000975528258147577
# Trainloss at epoch 5: 1.0523860893751447
# Train intent accuracy:  75.33333333333333
# Valid intent accuracy:  64.75
# Learning rate after initialization:  0.0009648882429441261
# Trainloss at epoch 6: 0.9011955465141096
# Train intent accuracy:  79.83333333333333
# Valid intent accuracy:  67.25
# Learning rate after initialization:  0.0009524135262330102
# Trainloss at epoch 7: 0.8266208642407468
# Train intent accuracy:  81.25
# Valid intent accuracy:  68.5
# Learning rate after initialization:  0.0009381533400219322
# Trainloss at epoch 8: 0.753538020347294
# Train intent accuracy:  82.0
# Valid intent accuracy:  71.0
# Learning rate after initialization:  0.000922163962751008
# Trainloss at epoch 9: 0.6785153472109845
# Train intent accuracy:  84.33333333333334
# Valid intent accuracy:  72.25
# Learning rate after initialization:  0.0009045084971874742
# Trainloss at epoch 10: 0.6394375507768831
# Train intent accuracy:  84.33333333333334
# Valid intent accuracy:  71.75
# Learning rate after initialization:  0.0008852566213878953
# Trainloss at epoch 11: 0.5773201655400427
# Train intent accuracy:  86.5
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.0008644843137107065
# Trainloss at epoch 12: 0.5360817556318483
# Train intent accuracy:  86.83333333333333
# Valid intent accuracy:  71.25
# Learning rate after initialization:  0.0008422735529643454
# Trainloss at epoch 13: 0.4976149491573635
# Train intent accuracy:  89.0
# Valid intent accuracy:  73.25
# Learning rate after initialization:  0.0008187119948743456
# Trainloss at epoch 14: 0.46837490326479864
# Train intent accuracy:  90.0
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.0007938926261462369
# Trainloss at epoch 15: 0.45990714470022603
# Train intent accuracy:  88.33333333333333
# Valid intent accuracy:  75.5
# Learning rate after initialization:  0
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  77.5
# Learning rate after initialization:  7.783603724899248e-05
# Trainloss at epoch 41: 0.22728256371460462
# Train intent accuracy:  96.5
# Valid intent accuracy:  77.25
# Learning rate after initialization:  6.184665997806835e-05
# Trainloss at epoch 42: 0.2063320034036511
# Train intent accuracy:  96.83333333333334
# Valid intent accuracy:  77.25
# Learning rate after initialization:  4.7586473766990335e-05
# Trainloss at epoch 43: 0.2199568074000509
# Train intent accuracy:  96.66666666666667
# Valid intent accuracy:  77.75
# Learning rate after initialization:  3.5111757055874265e-05
# Trainloss at epoch 44: 0.22665858543232867
# Train intent accuracy:  96.25
# Valid intent accuracy:  77.25
# Learning rate after initialization:  2.4471741852423238e-05
# Trainloss at epoch 45: 0.2127419961126227
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  77.5
# Learning rate after initialization:  1.5708419435684463e-05
# Trainloss at epoch 46: 0.22383533751494006
# Train intent accuracy:  95.75
# Valid intent accuracy:  77.25
# Learning rate after initialization:  8.856374635655697e-06
# Trainloss at epoch 47: 0.21197747282291712
# Train intent accuracy:  96.83333333333334
# Valid intent accuracy:  77.25
# Learning rate after initialization:  3.942649342761118e-06
# Trainloss at epoch 48: 0.22905082784985242
# Train intent accuracy:  96.08333333333333
# Valid intent accuracy:  77.25
# Learning rate after initialization:  9.866357858642204e-07
# Trainloss at epoch 49: 0.2091239831949535
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  77.25
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.528769091555947
# Train intent accuracy:  15.666666666666668
# Valid intent accuracy:  36.5
# Learning rate after initialization:  0.000999013364214136
# Trainloss at epoch 1: 2.421361324034239
# Train intent accuracy:  50.0
# Valid intent accuracy:  48.75
# Learning rate after initialization:  0.0009960573506572399
# Trainloss at epoch 2: 1.8297601624539024
# Train intent accuracy:  63.16666666666667
# Valid intent accuracy:  54.75
# Learning rate after initialization:  0.0009911436253643446
# Trainloss at epoch 3: 1.4582942598744442
# Train intent accuracy:  70.33333333333334
# Valid intent accuracy:  60.75000000000001
# Learning rate after initialization:  0.0009842915805643158
# Trainloss at epoch 4: 1.196852390703402
# Train intent accuracy:  75.91666666666667
# Valid intent accuracy:  63.5
# Learning rate after initialization:  0.000975528258147577
# Trainloss at epoch 5: 1.0318582481459568
# Train intent accuracy:  77.08333333333334
# Valid intent accuracy:  67.0
# Learning rate after initialization:  0.0009648882429441261
# Trainloss at epoch 6: 0.9092689015363392
# Train intent accuracy:  80.08333333333333
# Valid intent accuracy:  68.0
# Learning rate after initialization:  0.0009524135262330102
# Trainloss at epoch 7: 0.7910276525898984
# Train intent accuracy:  83.16666666666667
# Valid intent accuracy:  68.0
# Learning rate after initialization:  0.0009381533400219322
# Trainloss at epoch 8: 0.7092488808067221
# Train intent accuracy:  85.0
# Valid intent accuracy:  71.5
# Learning rate after initialization:  0.000922163962751008
# Trainloss at epoch 9: 0.6838764360076502
# Train intent accuracy:  84.33333333333334
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.0009045084971874742
# Trainloss at epoch 10: 0.6114062957073513
# Train intent accuracy:  86.58333333333333
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0
# Train intent accuracy:  97.33333333333334
# Valid intent accuracy:  75.0
# Learning rate after initialization:  7.783603724899248e-05
# Trainloss at epoch 41: 0.23703893117214503
# Train intent accuracy:  95.66666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  6.184665997806835e-05
# Trainloss at epoch 42: 0.22377556503603332
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  75.0
# Learning rate after initialization:  4.7586473766990335e-05
# Trainloss at epoch 43: 0.22195053218226685
# Train intent accuracy:  96.75
# Valid intent accuracy:  75.5
# Learning rate after initialization:  3.5111757055874265e-05
# Trainloss at epoch 44: 0.21749897850187203
# Train intent accuracy:  96.66666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  2.4471741852423238e-05
# Trainloss at epoch 45: 0.22494461661890933
# Train intent accuracy:  96.25
# Valid intent accuracy:  75.0
# Learning rate after initialization:  1.5708419435684463e-05
# Trainloss at epoch 46: 0.2172849119493836
# Train intent accuracy:  96.58333333333333
# Valid intent accuracy:  75.0
# Learning rate after initialization:  8.856374635655697e-06
# Trainloss at epoch 47: 0.22008620829958664
# Train intent accuracy:  97.0
# Valid intent accuracy:  75.0
# Learning rate after initialization:  3.942649342761118e-06
# Trainloss at epoch 48: 0.22415852409444356
# Train intent accuracy:  96.16666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  9.866357858642204e-07
# Trainloss at epoch 49: 0.22801900419749713
# Train intent accuracy:  96.16666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.542776063868874
# Train intent accuracy:  14.75
# Valid intent accuracy:  33.5
# Learning rate after initialization:  0.000999013364214136
# Trainloss at epoch 1: 2.4622036030417993
# Train intent accuracy:  48.5
# Valid intent accuracy:  50.24999999999999
# Learning rate after initialization:  0.0009960573506572399
# Trainloss at epoch 2: 1.8694684034899662
# Train intent accuracy:  62.5
# Valid intent accuracy:  58.75
# Learning rate after initialization:  0.0009911436253643446
# Trainloss at epoch 3: 1.482785535486121
# Train intent accuracy:  68.75
# Valid intent accuracy:  63.5
# Learning rate after initialization:  0.0009842915805643158
# Trainloss at epoch 4: 1.2339570004689067
# Train intent accuracy:  74.41666666666666
# Valid intent accuracy:  63.74999999999999
# Learning rate after initialization:  0.000975528258147577
# Trainloss at epoch 5: 1.0829013272335655
# Train intent accuracy:  76.16666666666667
# Valid intent accuracy:  69.75
# Learning rate after initialization:  0.0009648882429441261
# Trainloss at epoch 6: 0.9400868368776221
# Train intent accuracy:  79.08333333333334
# Valid intent accuracy:  71.5
# Learning rate after initialization:  0.0009524135262330102
# Trainloss at epoch 7: 0.8446798622608185
# Train intent accuracy:  80.83333333333333
# Valid intent accuracy:  69.25
# Learning rate after initialization:  0.0009381533400219322
# Trainloss at epoch 8: 0.7529674815504175
# Train intent accuracy:  83.33333333333334
# Valid intent accuracy:  72.0
# Learning rate after initialization:  0.000922163962751008
# Trainloss at epoch 9: 0.6653827899380734
# Train intent accuracy:  86.33333333333333
# Valid intent accuracy:  73.0
# Learning rate after initialization:  0.0009045084971874742
# Trainloss at epoch 10: 0.6281755660709581
# Train intent accuracy:  86.25
# Valid intent accuracy:  73.25
# Learning rate after initialization:  0.0008852566213878953
# Trainloss at epoch 11: 0.6055581906908437
# Train intent accuracy:  86.08333333333333
# Valid intent accuracy:  72.75
# Learning rate after initialization:  0.0008644843137107065
# Trainloss at epoch 12: 0.5429663454231463
# Train intent accuracy:  88.5
# Valid intent accuracy:  71.75
# Learning rate after initialization:  0.0008422735529643454
# Trainloss at epoch 13: 0.5187546195168244
# Train intent accuracy:  89.41666666666667
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  76.5
# Learning rate after initialization:  0.00013551568628929436
# Trainloss at epoch 38: 0.23127879516074532
# Train intent accuracy:  96.25
# Valid intent accuracy:  76.0
# Learning rate after initialization:  0.0001147433786121053
# Trainloss at epoch 39: 0.23134374794991394
# Train intent accuracy:  95.83333333333334
# Valid intent accuracy:  77.0
# Learning rate after initialization:  9.549150281252633e-05
# Trainloss at epoch 40: 0.2418695562764218
# Train intent accuracy:  95.75
# Valid intent accuracy:  76.75
# Learning rate after initialization:  7.783603724899248e-05
# Trainloss at epoch 41: 0.2369242710502524
# Train intent accuracy:  96.5
# Valid intent accuracy:  76.75
# Learning rate after initialization:  6.184665997806835e-05
# Trainloss at epoch 42: 0.22753438059436648
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  76.75
# Learning rate after initialization:  4.7586473766990335e-05
# Trainloss at epoch 43: 0.22761224641611702
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  76.5
# Learning rate after initialization:  3.5111757055874265e-05
# Trainloss at epoch 44: 0.23038256736962417
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  76.75
# Learning rate after initialization:  2.4471741852423238e-05
# Trainloss at epoch 45: 0.23123305526218915
# Train intent accuracy:  96.16666666666667
# Valid intent accuracy:  76.75
# Learning rate after initialization:  1.5708419435684463e-05
# Trainloss at epoch 46: 0.21997586990657605
# Train intent accuracy:  96.08333333333333
# Valid intent accuracy:  77.0
# Learning rate after initialization:  8.856374635655697e-06
# Trainloss at epoch 47: 0.2186062379102958
# Train intent accuracy:  97.0
# Valid intent accuracy:  77.0
# Learning rate after initialization:  3.942649342761118e-06
# Trainloss at epoch 48: 0.2253242593846823
# Train intent accuracy:  97.33333333333334
# Valid intent accuracy:  77.0
# Learning rate after initialization:  9.866357858642204e-07
# Trainloss at epoch 49: 0.22830266505479813
# Train intent accuracy:  96.75
# Valid intent accuracy:  77.0
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 39986
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 3.5288260986930444
# Train intent accuracy:  13.416666666666666
# Valid intent accuracy:  38.0
# Learning rate after initialization:  0.000999013364214136
# Trainloss at epoch 1: 2.473417652280707
# Train intent accuracy:  47.333333333333336
# Valid intent accuracy:  53.5
# Learning rate after initialization:  0.0009960573506572399
# Trainloss at epoch 2: 1.8768215650006344
# Train intent accuracy:  64.0
# Valid intent accuracy:  57.49999999999999
# Learning rate after initialization:  0.0009911436253643446
# Trainloss at epoch 3: 1.482172573867597
# Train intent accuracy:  70.25
# Valid intent accuracy:  61.0
# Learning rate after initialization:  0.0009842915805643158
# Trainloss at epoch 4: 1.2380535853536505
# Train intent accuracy:  75.33333333333333
# Valid intent accuracy:  64.75
# Learning rate after initialization:  0.000975528258147577
# Trainloss at epoch 5: 1.0500138276501705
# Train intent accuracy:  78.08333333333334
# Valid intent accuracy:  64.75
# Learning rate after initialization:  0.0009648882429441261
# Trainloss at epoch 6: 0.9217568745738581
# Train intent accuracy:  81.0
# Valid intent accuracy:  67.0
# Learning rate after initialization:  0.0009524135262330102
# Trainloss at epoch 7: 0.8223996334954312
# Train intent accuracy:  81.91666666666667
# Valid intent accuracy:  70.75
# Learning rate after initialization:  0.0009381533400219322
# Trainloss at epoch 8: 0.7540150386722464
# Train intent accuracy:  83.66666666666667
# Valid intent accuracy:  69.5
# Learning rate after initialization:  0.000922163962751008
# Trainloss at epoch 9: 0.678899128970347
# Train intent accuracy:  86.0
# Valid intent accuracy:  70.0
# Learning rate after initialization:  0.0009045084971874742
# Trainloss at epoch 10: 0.6095928189001585
# Train intent accuracy:  88.25
# Valid intent accuracy:  71.75
# Learning rate after initialization:  0.0008852566213878953
# Trainloss at epoch 11: 0.5858604398212934
# Train intent accuracy:  87.0
# Valid intent accuracy:  71.25
# Learning rate after initialization:  0.0008644843137107065
# Trainloss at epoch 12: 0.5520895915596109
# Train intent accuracy:  87.58333333333333
# Valid intent accuracy:  71.0
# Learning rate after initialization:  0.0008422735529643454
# Trainloss at epoch 13: 0.49076107771773086
# Train intent accuracy:  90.5
# Valid intent accuracy:  71.0
# Learning rate after initialization:  0.0008187119948743456
# Trainloss at epoch 14: 0.48537360053313405
# Train intent accuracy:  88.58333333333334
# Valid intent accuracy:  70.5
# Learning rate after initialization:  0.0007938926261462369
# Trainloss at epoch 15: 0.4652002869467986
# Train intent accuracy:  89.66666666666666
# Valid intent accuracy:  71.25
# Learning rate after initialization:  0.000767913397489498
# Trainloss at epoch 16: 0.42603446700071035
# Train intent accuracy:  90.66666666666666
# Valid intent accuracy:  74.0
# Learning rate after initialization:  0.0007408768370508574
# Trainloss at epoch 17: 0.40496591596226944
# Train intent accuracy:  91.83333333333333
# Valid intent accuracy:  73.5
# Learning rate after initialization:  0.0007128896457825359
# Trainloss at epoch 18: 0.38378629990314184
# Train intent accuracy:  91.83333333333333
# Valid intent accuracy:  72.25
# Learning rate after initialization:  0.0006840622763423389
# Trainloss at epoch 19: 0.3632804916093224
# Train intent accuracy:  93.0
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.0006545084971874734
# Trainloss at epoch 20: 0.360939764270657
# Train intent accuracy:  92.83333333333333
# Valid intent accuracy:  72.5
# Learning rate after initialization:  0.0006243449435824276
# Trainloss at epoch 21: 0.32918838568423925
# Train intent accuracy:  93.08333333333333
# Valid intent accuracy:  74.75
# Learning rate after initialization:  0.0005936906572928625
# Trainloss at epoch 22: 0.32093035900279093
# Train intent accuracy:  94.0
# Valid intent accuracy:  73.75
# Learning rate after initialization:  0.000562666616782152
# Trainloss at epoch 23: 0.30880209019309596
# Train intent accuracy:  94.5
# Valid intent accuracy:  74.0
# Learning rate after initialization:  0.0005313952597646564
# Trainloss at epoch 24: 0.3049361670487805
# Train intent accuracy:  94.5
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.0004999999999999999
# Trainloss at epoch 25: 0.3188544358862074
# Train intent accuracy:  93.66666666666667
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.00046860474023534336
# Trainloss at epoch 26: 0.30480602775749405
# Train intent accuracy:  94.66666666666667
# Valid intent accuracy:  76.25
# Learning rate after initialization:  0.0004373333832178479
# Trainloss at epoch 27: 0.28425917147021545
# Train intent accuracy:  94.66666666666667
# Valid intent accuracy:  74.75
# Learning rate after initialization:  0.0004063093427071379
# Trainloss at epoch 28: 0.27824743268521207
# Train intent accuracy:  94.41666666666667
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.00037565505641757273
# Trainloss at epoch 29: 0.24997954109781667
# Train intent accuracy:  96.33333333333334
# Valid intent accuracy:  74.5
# Learning rate after initialization:  0.0003454915028125263
# Trainloss at epoch 30: 0.2841866137950044
# Train intent accuracy:  94.0
# Valid intent accuracy:  75.5
# Learning rate after initialization:  0.0003159377236576611
# Trainloss at epoch 31: 0.26515953909409673
# Train intent accuracy:  94.91666666666667
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.0002871103542174638
# Trainloss at epoch 32: 0.24822713709191271
# Train intent accuracy:  96.08333333333333
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.00025912316294914245
# Trainloss at epoch 33: 0.24862396893532654
# Train intent accuracy:  95.83333333333334
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.00023208660251050172
# Trainloss at epoch 34: 0.24042125948165594
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  75.0
# Learning rate after initialization:  0.00020610737385376345
# Trainloss at epoch 35: 0.24776545853206985
# Train intent accuracy:  95.41666666666667
# Valid intent accuracy:  75.25
# Learning rate after initialization:  0.0001812880051256551
# Trainloss at epoch 36: 0.22852020357784472
# Train intent accuracy:  96.16666666666667
# Valid intent accuracy:  75.5
# Learning rate after initialization:  0.00015772644703565585
# Trainloss at epoch 37: 0.22601187621292315
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  75.5
# Learning rate after initialization:  0.00013551568628929436
# Trainloss at epoch 38: 0.22014083321157255
# Train intent accuracy:  96.75
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.0001147433786121053
# Trainloss at epoch 39: 0.22813019587805397
# Train intent accuracy:  96.25
# Valid intent accuracy:  76.25
# Learning rate after initialization:  9.549150281252633e-05
# Trainloss at epoch 40: 0.2230518542622265
# Train intent accuracy:  96.66666666666667
# Valid intent accuracy:  76.0
# Learning rate after initialization:  7.783603724899248e-05
# Trainloss at epoch 41: 0.22114389428966924
# Train intent accuracy:  96.91666666666666
# Valid intent accuracy:  75.5
# Learning rate after initialization:  6.184665997806835e-05
# Trainloss at epoch 42: 0.21766223052614614
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  75.5
# Learning rate after initialization:  4.7586473766990335e-05
# Trainloss at epoch 43: 0.2246739015375313
# Train intent accuracy:  96.5
# Valid intent accuracy:  75.5
# Learning rate after initialization:  3.5111757055874265e-05
# Trainloss at epoch 44: 0.2268810256531364
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  76.0
# Learning rate after initialization:  2.4471741852423238e-05
# Trainloss at epoch 45: 0.22666512821850024
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  75.75
# Learning rate after initialization:  1.5708419435684463e-05
# Trainloss at epoch 46: 0.2203819394895905
# Train intent accuracy:  96.0
# Valid intent accuracy:  75.75
# Learning rate after initialization:  8.856374635655697e-06
# Trainloss at epoch 47: 0.23349709553938164
# Train intent accuracy:  96.16666666666667
# Valid intent accuracy:  75.75
# Learning rate after initialization:  3.942649342761118e-06
# Trainloss at epoch 48: 0.2234549216533962
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  75.75
# Learning rate after initialization:  9.866357858642204e-07
# Trainloss at epoch 49: 0.22883963212370872
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  75.75
# Learning rate after initialization:  0.0
# Folds accuracy:  [0.7575, 0.7675, 0.735, 0.7475, 0.725]
# Avg accuracy over the 5 fold(s):  0.7464999999999999
# Std accuracy over the 5 fold(s):  0.01521512405470293
# Training time 4:00:03

# %% [markdown]
# ## Full

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'full-FT'
# Out:
# 2025-03-14 13:18:16.436584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741958296.457558   91024 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741958296.464038   91024 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 13:18:16.485593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='full-FT', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 85746482
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 2.647767085778086
# Train intent accuracy:  34.333333333333336
# Valid intent accuracy:  61.25000000000001
# Learning rate after initialization:  4.995066821070677e-05
# Trainloss at epoch 1: 0.8173772010364031
# Train intent accuracy:  77.83333333333333
# Valid intent accuracy:  74.75
# Learning rate after initialization:  4.980286753286195e-05
# Trainloss at epoch 2: 0.32261793197769867
# Train intent accuracy:  91.58333333333334
# Valid intent accuracy:  83.0
# Learning rate after initialization:  4.9557181268217186e-05
# Trainloss at epoch 3: 0.2107664813336573
# Train intent accuracy:  94.41666666666667
# Valid intent accuracy:  81.75
# Learning rate after initialization:  4.921457902821575e-05
# Trainloss at epoch 4: 0.16305952073123894
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  82.0
# Learning rate after initialization:  4.87764129073788e-05
# Trainloss at epoch 5: 0.09527711214889821
# Train intent accuracy:  97.75
# Valid intent accuracy:  82.25
# Learning rate after initialization:  4.8244412147206243e-05
# Trainloss at epoch 6: 0
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 85746482
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 2.6034277552052547
# Train intent accuracy:  33.33333333333333
# Valid intent accuracy:  64.5
# Learning rate after initialization:  4.995066821070677e-05
# Trainloss at epoch 1: 0.7959039062261581
# Train intent accuracy:  80.25
# Valid intent accuracy:  82.5
# Learning rate after initialization:  4.980286753286195e-05
# Trainloss at epoch 2: 0.33979316879259913
# Train intent accuracy:  91.41666666666667
# Valid intent accuracy:  81.0
# Learning rate after initialization:  4.9557181268217186e-05
# Trainloss at epoch 3: 0.18763015134946295
# Train intent accuracy:  95.58333333333333
# Valid intent accuracy:  78.75
# Learning rate after initialization:  4.921457902821575e-05
# Trainloss at epoch 4: 0.1269865642840925
# Train intent accuracy:  97.08333333333333
# Valid intent accuracy:  84.5
# Learning rate after initialization:  4.87764129073788e-05
# Trainloss at epoch 5: 0.14219941532141284
# Train intent accuracy:  95.58333333333333
# Valid intent accuracy:  80.0
# Learning rate after initialization:  4.8244412147206243e-05
# Trainloss at epoch 6: 0.12720295894694955
# Train intent accuracy:  96.75
# Valid intent accuracy:  82.75
# Learning rate after initialization:  4.762067631165044e-05
# Trainloss at epoch 7: 0.09558631094956868
# Train intent accuracy:  97.16666666666667
# Valid intent accuracy:  81.5
# Learning rate after initialization:  4.6907667001096536e-05
# Trainloss at epoch 8: 0.09606782891052335
# Train intent accuracy:  97.41666666666666
# Valid intent accuracy:  81.0
# Learning rate after initialization:  4.6108198137550285e-05
# Trainloss at epoch 9: 0.05967742140944067
# Train intent accuracy:  98.25
# Valid intent accuracy:  81.5
# Learning rate after initialization:  4.522542485937359e-05
# Trainloss at epoch 10: 0.052772767939849904
# Train intent accuracy:  98.66666666666667
# Valid intent accuracy:  80.5
# Learning rate after initialization:  4.426283106939463e-05
# Trainloss at epoch 11: 0.08774518444643993
# Train intent accuracy:  98.16666666666667
# Valid intent accuracy:  87.25
# Learning rate after initialization:  4.322421568553519e-05
# Trainloss at epoch 12: 0.05997564778418133
# Train intent accuracy:  98.25
# Valid intent accuracy:  83.5
# Learning rate after initialization:  4.2113677648217144e-05
# Trainloss at epoch 13: 0.056239066676138656
# Train intent accuracy:  98.75
# Valid intent accuracy:  82.25
# Learning rate after initialization:  4.093559974371716e-05
# Trainloss at epoch 14: 0.03175765417491723
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  87.25
# Learning rate after initialization:  3.9694631307311775e-05
# Trainloss at epoch 15: 0.03908668199897205
# Train intent accuracy:  98.83333333333333
# Valid intent accuracy:  84.0
# Learning rate after initialization:  3.839566987447488e-05

# %%
# !python3 main.py --data_path dataset/ --is_AST True --dataset_name 'ESC-50' --method 'full-FT'
# Out:
# 2025-03-15 07:05:47.663475: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-15 07:05:47.682081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742022347.704254    1753 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742022347.710891    1753 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-15 07:05:47.733299: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(data_path='dataset/', seed=10, device='cuda', num_workers=4, model_ckpt_AST='MIT/ast-finetuned-audioset-10-10-0.4593', model_ckpt_wav='facebook/wav2vec2-base-960h', max_len_audio=128000, save_best_ckpt=False, output_path='/checkpoints', is_AST=True, dataset_name='ESC-50', method='full-FT', seq_or_par='parallel', reduction_rate_adapter=96, adapter_type='Pfeiffer', apply_residual=False, adapter_block='conformer', kernel_size=31, is_adapter_ablation=False, befafter='after', location='FFN', reduction_rate_moa=128, adapter_type_moa='Pfeiffer', location_moa='MHSA', adapter_module_moa='bottleneck', num_adapters=7, num_slots=1, normalize=False, reduction_rate_lora=64, alpha_lora=8, is_lora_ablation=False, lora_config='Wq,Wv', prompt_len_pt=24, prompt_len_prompt=25, is_deep_prompt=True, drop_prompt=0.0, is_few_shot_exp=False, few_shot_samples=64, use_wandb=False, project_name='', exp_name='', entity='')
# preprocessor_config.json: 100% 297/297 [00:00<00:00, 2.22MB/s]
# config.json: 100% 26.8k/26.8k [00:00<00:00, 77.6MB/s]
# model.safetensors: 100% 346M/346M [00:01<00:00, 333MB/s]
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 85746482
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 2.6477703734448084
# Train intent accuracy:  34.333333333333336
# Valid intent accuracy:  61.25000000000001
# Learning rate after initialization:  4.995066821070677e-05
# Trainloss at epoch 1: 0.817379040153403
# Train intent accuracy:  77.83333333333333
# Valid intent accuracy:  74.75
# Learning rate after initialization:  4.980286753286195e-05
# Trainloss at epoch 2: 0.32261873703253896
# Train intent accuracy:  91.58333333333334
# Valid intent accuracy:  83.0
# Learning rate after initialization:  4.9557181268217186e-05
# Trainloss at epoch 3: 0.21076657623052597
# Train intent accuracy:  94.41666666666667
# Valid intent accuracy:  81.75
# Learning rate after initialization:  4.921457902821575e-05
# Trainloss at epoch 4: 0.16305769676048504
# Train intent accuracy:  95.91666666666666
# Valid intent accuracy:  82.0
# Learning rate after initialization:  4.87764129073788e-05
# Trainloss at epoch 5: 0.09527296264116701
# Train intent accuracy:  97.75
# Valid intent accuracy:  82.25
# Learning rate after initialization:  4.8244412147206243e-05
# Trainloss at epoch 6: 0.09072606731206179
# Train intent accuracy:  97.5
# Valid intent accuracy:  79.75
# Learning rate after initialization:  4.762067631165044e-05
# Trainloss at epoch 7: 0
# Learning rate after initialization:  2.186666916089235e-05
# Trainloss at epoch 27: 0.009100244518393944
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  85.0
# Learning rate after initialization:  2.0315467135356853e-05
# Trainloss at epoch 28: 0.014693449263607985
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  85.5
# Learning rate after initialization:  1.8782752820878604e-05
# Trainloss at epoch 29: 0.015850488669361527
# Train intent accuracy:  99.58333333333333
# Valid intent accuracy:  87.75
# Learning rate after initialization:  1.7274575140626294e-05
# Trainloss at epoch 30: 0.004776377920183893
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.25
# Learning rate after initialization:  1.5796886182883042e-05
# Trainloss at epoch 31: 0.009781497938858689
# Train intent accuracy:  99.75
# Valid intent accuracy:  88.5
# Learning rate after initialization:  1.4355517710873172e-05
# Trainloss at epoch 32: 0.007862219433024476
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  89.25
# Learning rate after initialization:  1.295615814745711e-05
# Trainloss at epoch 33: 0.007070819307333103
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  91.0
# Learning rate after initialization:  1.160433012552507e-05
# Trainloss at epoch 34: 0.008301597845274955
# Train intent accuracy:  99.75
# Valid intent accuracy:  89.5
# Learning rate after initialization:  1.0305368692688161e-05
# Trainloss at epoch 35: 0.008447954294847716
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  89.25
# Learning rate after initialization:  9.064400256282746e-06
# Trainloss at epoch 36: 0.005131359770434517
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.25
# Learning rate after initialization:  7.886322351782783e-06
# Trainloss at epoch 37: 0.002383480445132591
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  88.75
# Learning rate after initialization:  6.7757843144647094e-06
# Trainloss at epoch 38: 0.0034647313089073194
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.5
# Learning rate after initialization:  5.7371689306052606e-06
# Trainloss at epoch 39: 0.006441645599184803
# Train intent accuracy:  99.75
# Valid intent accuracy:  88.75
# Learning rate after initialization:  4.77457514062631e-06
# Trainloss at epoch 40: 0.004076854417737769
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  88.75
# Learning rate after initialization:  3.8918018624496186e-06
# Trainloss at epoch 41: 0.006020176374907973
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  89.0
# Learning rate after initialization:  3.0923329989034115e-06
# Trainloss at epoch 42: 0.0009266290033242273
# Train intent accuracy:  100.0
# Valid intent accuracy:  89.25
# Learning rate after initialization:  2.379323688349512e-06
# Trainloss at epoch 43: 0.0004411606818106712
# Train intent accuracy:  100.0
# Valid intent accuracy:  89.5
# Learning rate after initialization:  1.7555878527937098e-06
# Trainloss at epoch 44: 0.0019091426250892446
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  89.5
# Learning rate after initialization:  1.2235870926211598e-06
# Trainloss at epoch 45: 0.0017626813764524598
# Train intent accuracy:  100.0
# Valid intent accuracy:  90.5
# Learning rate after initialization:  7.854209717842218e-07
# Trainloss at epoch 46: 0.003263708227773589
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  90.5
# Learning rate after initialization:  4.4281873178278385e-07
# Trainloss at epoch 47: 0.0007806865059568448
# Train intent accuracy:  100.0
# Valid intent accuracy:  90.5
# Learning rate after initialization:  1.9713246713805554e-07
# Trainloss at epoch 48: 0.004306138267183039
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  90.5
# Learning rate after initialization:  4.933178929321094e-08
# Trainloss at epoch 49: 0.013392471956122838
# Train intent accuracy:  99.75
# Valid intent accuracy:  90.5
# Learning rate after initialization:  0.0
# Some weights of ASTModel were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - audio_spectrogram_transformer.embeddings.position_embeddings: found shape torch.Size([1, 1214, 768]) in the checkpoint and torch.Size([1, 590, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Number of params of the model: 85746482
# Number of trainable params of the model: 85746482
# AST(
#   (model): ASTModel(
#     (embeddings): ASTEmbeddings(
#       (patch_embeddings): ASTPatchEmbeddings(
#         (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ASTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ASTLayer(
#           (attention): ASTSdpaAttention(
#             (attention): ASTSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ASTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ASTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ASTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classification_head): Linear(in_features=768, out_features=50, bias=True)
# )
# Start training for 50 epochs
# Trainloss at epoch 0: 2.603428668097446
# Train intent accuracy:  33.33333333333333
# Valid intent accuracy:  64.5
# Learning rate after initialization:  4.995066821070677e-05
# Trainloss at epoch 1: 0.7959041971909372
# Train intent accuracy:  80.25
# Valid intent accuracy:  82.5
# Learning rate after initialization:  4.980286753286195e-05
# Trainloss at epoch 2: 0.3397933240783842
# Train intent accuracy:  91.41666666666667
# Valid intent accuracy:  81.0
# Learning rate after initialization:  4.9557181268217186e-05
# Trainloss at epoch 3: 0.18763050005624168
# Train intent accuracy:  95.58333333333333
# Valid intent accuracy:  78.75
# Learning rate after initialization:  4.921457902821575e-05
# Trainloss at epoch 4: 0.12698659389034697
# Train intent accuracy:  97.08333333333333
# Valid intent accuracy:  84.5
# Learning rate after initialization:  4.87764129073788e-05
# Trainloss at epoch 5: 0.1422003469871063
# Train intent accuracy:  95.58333333333333
# Valid intent accuracy:  80.0
# Learning rate after initialization:  4.8244412147206243e-05
# Trainloss at epoch 6: 0.12720968789960208
# Train intent accuracy:  96.75
# Valid intent accuracy:  82.75
# Learning rate after initialization:  4.762067631165044e-05
# Trainloss at epoch 7: 0.09558783949499852
# Train intent accuracy:  97.16666666666667
# Valid intent accuracy:  81.5
# Learning rate after initialization:  4.6907667001096536e-05
# Trainloss at epoch 8: 0.09589680899424773
# Train intent accuracy:  97.41666666666666
# Valid intent accuracy:  80.75
# Learning rate after initialization:  4.6108198137550285e-05
# Trainloss at epoch 9: 0.0609821509202256
# Train intent accuracy:  98.16666666666667
# Valid intent accuracy:  81.0
# Learning rate after initialization:  4.522542485937359e-05
# Trainloss at epoch 10: 0.04575792894894747
# Train intent accuracy:  98.83333333333333
# Valid intent accuracy:  83.25
# Learning rate after initialization:  4.426283106939463e-05
# Trainloss at epoch 11: 0.10565050644800067
# Train intent accuracy:  97.5
# Valid intent accuracy:  85.75
# Learning rate after initialization:  4.322421568553519e-05
# Trainloss at epoch 12: 0.09756112191826105
# Train intent accuracy:  96.41666666666666
# Valid intent accuracy:  84.5
# Learning rate after initialization:  4.2113677648217144e-05
# Trainloss at epoch 13: 0.03768454031332543
# Train intent accuracy:  98.91666666666666
# Valid intent accuracy:  81.75
# Learning rate after initialization:  4.093559974371716e-05
# Trainloss at epoch 14: 0.058925607597063244
# Train intent accuracy:  98.25
# Valid intent accuracy:  79.75
# Learning rate after initialization:  3.9694631307311775e-05
# Trainloss at epoch 15: 0.04107287754059622
# Train intent accuracy:  98.83333333333333
# Valid intent accuracy:  83.75
# Learning rate after initialization:  3.839566987447488e-05
# Trainloss at epoch 16: 0.03836891567947245
# Train intent accuracy:  98.91666666666666
# Valid intent accuracy:  85.5
# Learning rate after initialization:  3.7043841852542834e-05
# Trainloss at epoch 17: 0.02413506104341267
# Train intent accuracy:  99.5
# Valid intent accuracy:  84.0
# Learning rate after initialization:  3.564448228912675e-05
# Trainloss at epoch 18: 0.06791765930278129
# Train intent accuracy:  98.16666666666667
# Valid intent accuracy:  82.75
# Learning rate after initialization:  3.420311381711689e-05
# Trainloss at epoch 19: 0.07545222201703214
# Train intent accuracy:  98.16666666666667
# Valid intent accuracy:  80.75
# Learning rate after initialization:  3.2725424859373596e-05
# Trainloss at epoch 20: 0.05847765506539298
# Train intent accuracy:  98.58333333333333
# Valid intent accuracy:  86.5
# Learning rate after initialization:  3.121724717912129e-05
# Trainloss at epoch 21: 0.018036703006241862
# Train intent accuracy:  99.5
# Valid intent accuracy:  83.5
# Learning rate after initialization:  2.9684532864643038e-05
# Trainloss at epoch 22: 0.012285125196764344
# Train intent accuracy:  99.75
# Valid intent accuracy:  89.25
# Learning rate after initialization:  2.813333083910754e-05
# Trainloss at epoch 23: 0.01867423754026133
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  84.5
# Learning rate after initialization:  2.656976298823276e-05
# Trainloss at epoch 24: 0.03172941195110692
# Train intent accuracy:  99.25
# Valid intent accuracy:  82.5
# Learning rate after initialization:  2.4999999999999944e-05
# Trainloss at epoch 25: 0.013118150892152795
# Train intent accuracy:  99.5
# Valid intent accuracy:  83.0
# Learning rate after initialization:  2.343023701176712e-05
# Trainloss at epoch 26: 0.025558522790609123
# Train intent accuracy:  99.33333333333333
# Valid intent accuracy:  84.25
# Learning rate after initialization:  2.186666916089235e-05
# Trainloss at epoch 27: 0.028354497002989153
# Train intent accuracy:  99.41666666666666
# Valid intent accuracy:  85.25
# Learning rate after initialization:  2.0315467135356853e-05
# Trainloss at epoch 28: 0.010525954969987077
# Train intent accuracy:  99.75
# Valid intent accuracy:  83.25
# Learning rate after initialization:  1.8782752820878604e-05
# Trainloss at epoch 29: 0.005154540748519234
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  85.5
# Learning rate after initialization:  1.7274575140626294e-05
# Trainloss at epoch 30: 0.016902117299124303
# Train intent accuracy:  99.66666666666667
# Valid intent accuracy:  83.0
# Learning rate after initialization:  1.5796886182883042e-05
# Trainloss at epoch 31: 0.013361861549415871
# Train intent accuracy:  99.5
# Valid intent accuracy:  87.0
# Learning rate after initialization:  1.4355517710873172e-05
# Trainloss at epoch 32: 0.007936739265508214
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.75
# Learning rate after initialization:  1.295615814745711e-05
# Trainloss at epoch 33: 0.004584750341325018
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.5
# Learning rate after initialization:  1.160433012552507e-05
# Trainloss at epoch 34: 0.0008802533067003088
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.0
# Learning rate after initialization:  1.0305368692688161e-05
# Trainloss at epoch 35: 0.007613369626740582
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  86.25
# Learning rate after initialization:  9.064400256282746e-06
# Trainloss at epoch 36: 0.00442550021781292
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  86.0
# Learning rate after initialization:  7.886322351782783e-06
# Trainloss at epoch 37: 0.0014020113449078053
# Train intent accuracy:  100.0
# Valid intent accuracy:  85.25
# Learning rate after initialization:  6.7757843144647094e-06
# Trainloss at epoch 38: 0.0011330390016634116
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.25
# Learning rate after initialization:  5.7371689306052606e-06
# Trainloss at epoch 39: 0.00044831914955897157
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.5
# Learning rate after initialization:  4.77457514062631e-06
# Trainloss at epoch 40: 0.001067194539293843
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.0
# Learning rate after initialization:  3.8918018624496186e-06
# Trainloss at epoch 41: 0.00046548679490929077
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.25
# Learning rate after initialization:  3.0923329989034115e-06
# Trainloss at epoch 42: 0.000625859128041683
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.75
# Learning rate after initialization:  2.379323688349512e-06
# Trainloss at epoch 43: 0.003057771100812763
# Train intent accuracy:  99.91666666666667
# Valid intent accuracy:  87.5
# Learning rate after initialization:  1.7555878527937098e-06
# Trainloss at epoch 44: 0.0013819746669277695
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.75
# Learning rate after initialization:  1.2235870926211598e-06
# Trainloss at epoch 45: 0.008102931289422008
# Train intent accuracy:  99.83333333333333
# Valid intent accuracy:  87.5
# Learning rate after initialization:  7.854209717842218e-07
# Trainloss at epoch 46: 0.0010506150432966503
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.5
# Learning rate after initialization:  4.4281873178278385e-07
# Trainloss at epoch 47: 0.01308174148289254
# Train intent accuracy:  99.75
# Valid intent accuracy:  87.5
# Learning rate after initialization:  1.9713246713805554e-07
# Trainloss at epoch 48: 0.000590714766172153
# Train intent accuracy:  100.0
# Valid intent accuracy:  87.5
# Learning rate after initialization:  4.933178929321094e-08
# Trainloss at epoch 49: 0.006542048165819755
# Train intent accuracy:  99.75
# Valid intent accuracy:  87.5
# Learning rate after initialization:  0.0
# Folds accuracy:  [0.8725, 0.8825, 0.865, 0.8725, 0.885]
# Avg accuracy over the 5 fold(s):  0.8755000000000001
# Std accuracy over the 5 fold(s):  0.007314369419163884
# Training time 4:23:33
